# %% [markdown]
# # Normilizer for Richmond Lattimore's translation of the Odyssey
#
# ### [—————————————pipeline—————————————]
# ### »——raw—»—clean—»—NORMALIZE—»—dataframe——»
#
# Solid and clean copy. Here are some characteristics.
#
# ## Before
# - Only the text
# - Keep book numbers: 'Book I',…'Book XXIV'
# - No numeral digits (if in book title, changed to Roman)
#
# ## After
# - clean text: only alphabetic characters
# - kept syntactical punctuation (. , ; : - " ') for future analysis
# - kept one line = one verse; a line break structure for prosodic analysis
# - kept book titles (because some book's first lines are repeated 19 times in the text)
# - removed macron and accents
# - removed line numbers
# - removed numeral digits
# - strpped empty lines

# %%
translator = "Lattimore"
filepath = f"/Users/debr/odysseys_en/cleaned_txts/Odyssey_{translator}_Cleaned.txt"

# %%
# Step 1: read txt and remove book's headers
with open(filepath, 'r') as file:
    lines = file.readlines()

new_lines = [line for line in lines if line.strip() != ''] # Remove empty lines

# Print a preview of the processed text
text = "".join(new_lines)
print(text[:100])
# Out:
# BOOK I
# Tell me, Muse, of the man of many ways, who was driven
# far journeys, after he had sacked Troy

# %%
new_lines
# Out:
# ['BOOK I\n',
#  'Tell me, Muse, of the man of many ways, who was driven\n',
#  "far journeys, after he had sacked Troy's sacred citadel.\n",
#  'Many were they whose cities he saw, whose minds he learned of,\n',
#  'many the pains he suffered in his spirit on the wide sea,\n',
#  '5 struggling for his own life and the homecoming of his companions.\n',
#  'Even so he could not save his companions, hard though\n',
#  'he strove to; they were destroyed by their own wild recklessness, fools,\n',
#  'who devoured the oxen of Helios, the Sun God, and he took away the day\n',
#  'of their homecoming. From some point\n',
#  '10 here, goddess, daughter of Zeus, speak, and begin our story.\n',
#  'Then all the others, as many as fled sheer destruction, were at home\n',
#  'now, having escaped the sea and the fighting.\n',
#  'This one alone, longing for his wife and his homecoming,\n',
#  'was detained by the queenly nymph Kalypso, bright among goddesses, 15\n',
#  'in her hollowed caverns, desiring that he should be her husband.\n',
#  'But when in the circling of the years that very year came in which the gods\n',
#  'had spun for him his time of homecoming to Ithaka, not even then was he\n',
#  'free of his trials nor among his own people. But all the gods pitied him\n',
#  '20 except Poseidon; he remained relentlessly angry with godlike Odysseus,\n',
#  'until his return to his own country.\n',
#  'But Poseidon was gone now to visit the far Aithiopians,\n',
#  'Aithiopians, most distant of men, who live divided,\n',
#  'some at the setting of Hyperion, some at his rising,\n',
#  'The council of the gods\n',
#  '25 to receive a hecatomb of bulls and rams. There he sat at the feast and took\n',
#  'his pleasure. Meanwhile the other Olympian gods were gathered together\n',
#  'in the halls of Zeus.\n',
#  'First among them to speak was the father of gods and mortals,\n',
#  'for he was thinking in his heart of stately Aigisthos, 30 whom Orestes,\n',
#  "Agamemnon's far-famed son, had murdered. Remembering him he spoke\n",
#  'now before the immortals: ‘Oh for shame, how the mortals put the blame\n',
#  'upon us\n',
#  'gods, for they say evils come from us, but it is they, rather,\n',
#  'who by their own recklessness win sorrow beyond what is given,\n',
#  '35 as now lately, beyond what was given, Aigisthos married the wife of\n',
#  "Atreus' son, and murdered him on his homecoming, though he knew it\n",
#  'was sheer destruction, for we ourselves had told him, sending Hermes, the\n',
#  'mighty watcher, Argeïphontes,\n',
#  'not to kill the man, nor court his lady for marriage;\n',
#  '40 for vengeance would come on him from Orestes, son of Atreides,\n',
#  'whenever he came of age and longed for his own country.\n',
#  'So Hermes told him, but for all his kind intention he could not\n',
#  "persuade the mind of Aigisthos. And now he has paid for everything.'\n",
#  'Then in turn the goddess gray-eyed Athene answered him: 45 ‘Son of\n',
#  'Kronos, our father, O lordliest of the mighty, Aigisthos indeed has been\n',
#  'struck down in a death well merited.\n',
#  'Let any other man who does thus perish as he did.\n',
#  'But the heart in me is torn for the sake of wise Odysseus,\n',
#  'unhappy man, who still, far from his friends, is suffering\n',
#  '50 griefs, on the sea-washed island, the navel of all the waters, a wooded\n',
#  'island, and there a goddess has made her dwelling place; she is daughter\n',
#  'of malignant Atlas, who has discovered all the depths of the sea, and\n',
#  'himself sustains the towering\n',
#  'columns which bracket earth and sky and hold them together.\n',
#  '55 This is his daughter; she detains the grieving, unhappy man, and ever with\n',
#  'soft and flattering words she works to charm him to forget Ithaka; and yet\n',
#  'Odysseus,\n',
#  'straining to get sight of the very smoke uprising\n',
#  'from his own country, longs to die. But you, Olympian,\n',
#  '60 the heart in you is heedless of him. Did not Odysseus do you grace by the\n',
#  'ships of the Argives, making sacrifice in wide Troy? Why, Zeus, are you\n',
#  'now so harsh with him?’\n',
#  'Then in turn Zeus who gathers the clouds made answer:\n',
#  'and the wrath of Poseidon\n',
#  "‘My child, what sort of word escaped your teeth's barrier?\n",
#  '65 How could I forget Odysseus the godlike, he who is beyond all other men\n',
#  'in mind, and who beyond others has given sacrifice to the gods, who hold\n',
#  'wide heaven?\n',
#  'It is the Earth Encircler Poseidon who, ever relentless,\n',
#  'nurses a grudge because of the Cyclops, whose eye he blinded;\n',
#  '70 for Polyphemos like a god, whose power is greatest over all the Cyclopes.\n',
#  'Thoösa, a nymph, was his mother, and she was daughter of Phorkys, lord\n',
#  'of the barren salt water.\n',
#  'She in the hollows of the caves had lain with Poseidon.\n',
#  'For his sake Poseidon, shaker of the earth, although he does not\n',
#  '75 kill Odysseus, yet drives him back from the land of his fathers. But come,\n',
#  'let all of us who are here work out his homecoming and see to it that he\n',
#  'returns. Poseidon shall put away\n',
#  'his anger; for all alone and against the will of the other\n',
#  'immortal gods united he can accomplish nothing.’\n',
#  '80 Then in turn the goddess gray-eyed Athene answered him: ‘Son of Kronos,\n',
#  'our father, O lordliest of the mighty, if in truth this is pleasing to the\n',
#  'blessed immortals\n',
#  'that Odysseus of the many designs shall return home, then\n',
#  'let us dispatch Hermes, the guide, the slayer of Argos,\n',
#  '85 to the island of Ogygia, so that with all speed he may announce to the\n',
#  'lovely-haired nymph our absolute purpose, the homecoming of enduring\n',
#  'Odysseus, that he shall come back.\n',
#  'But I shall make my way to Ithaka, so that I may\n',
#  'stir up his son a little, and put some confidence in him\n',
#  '90 to summon into assembly the flowing-haired Achaians and make a\n',
#  'statement to all the suitors, who now forever slaughter his crowding sheep\n',
#  'and lumbering horn-curved cattle;\n',
#  'and I will convey him into Sparta and to sandy Pylos\n',
#  "to ask after his dear father's homecoming, if he can hear something, 95 and\n",
#  'so that among people he may win a good reputation.’\n',
#  'Speaking so she bound upon her feet the fair sandals, golden and\n',
#  'immortal, that carried her over the water as over the dry boundless earth\n',
#  "abreast of the wind's blast.\n",
#  'Then she caught up a powerful spear, edged with sharp bronze,\n',
#  '100 heavy, huge, thick, wherewith she beats down the battalions of fighting\n',
#  'men, against whom she of the mighty father is angered,\n',
#  'and descended in a flash of speed from the peaks of Olympos,\n',
#  'Athene disguised as Mentes\n',
#  'and lighted in the land of Ithaka, at the doors of Odysseus\n',
#  'at the threshold of the court, and in her hand was the bronze spear.\n',
#  '105 She was disguised as a friend, leader of the Taphians, Mentes.\n',
#  'There she found the haughty suitors. They at the moment\n',
#  'in front of the doors were amusing their spirits with draughts games, sitting\n',
#  'about on skins of cattle whom they had slaughtered\n',
#  'themselves, and about them, of their heralds and hard-working henchmen,\n',
#  '110 some at the mixing bowls were combining wine and water,\n',
#  'while others again with porous sponges were wiping the tables\n',
#  'and setting them out, and others cutting meat in quantities.\n',
#  'Now far the first to see Athene was godlike Telemachos, as he sat\n',
#  'among the suitors, his heart deep grieving within him,\n',
#  '115 imagining in his mind his great father, how he might come back\n',
#  'and all throughout the house might cause the suitors to scatter,\n',
#  'and hold his rightful place and be lord of his own possessions.\n',
#  'With such thoughts, sitting among the suitors, he saw Athene\n',
#  'and went straight to the forecourt, the heart within him scandalized 120\n',
#  'that a guest should still be standing at the doors. He stood beside her and\n',
#  'took her by the right hand, and relieved her of the bronze spear, and spoke\n',
#  'to her and addressed her in winged words: ‘Welcome, stranger.\n',
#  'You shall be entertained as a guest among us. Afterward,\n',
#  'when you have tasted dinner, you shall tell us what your need is.’\n',
#  '125 So speaking he led the way, and Pallas Athene followed him. Now, when\n',
#  'the two of them were inside the lofty dwelling, he took the spear he\n',
#  'carried and set it against a tall column\n',
#  'in a rack for spears, of polished wood, where indeed there were other\n',
#  'spears of patient-hearted Odysseus standing in numbers,\n',
#  '130 and he led her and seated her in a chair, with a cloth to sit on, the chair\n',
#  'splendid and elaborate. For her feet there was a footstool.\n',
#  'For himself, he drew a painted bench next her, apart from the others, the\n',
#  'suitors, for fear the guest, made uneasy by the uproar,\n',
#  'might lose his appetite there among overbearing people,\n',
#  '135 and so he might also ask him about his absent father.\n',
#  'A maidservant brought water for them and poured it from a splendid and\n',
#  'golden pitcher, holding it above a silver basin\n',
#  'for them to wash, and she pulled a polished table before them.\n',
#  'A grave housekeeper brought in the bread and served it to them,\n',
#  '140 adding many good things to it, generous with her provisions,\n',
#  'while a carver lifted platters of all kinds of meat and set them\n',
#  'visits Telemachos\n',
#  'in front of them, and placed beside them the golden goblets,\n',
#  'and a herald, going back and forth, poured the wine for them.\n',
#  'Then the haughty suitors came in, and all of them straightway\n',
#  '145 took their places in order on chairs and along the benches,\n',
#  'and their heralds poured water over their hands for them to wash with, and\n',
#  'the serving maids brought them bread heaped up in the baskets, and the\n',
#  'young men filled the mixing bowls with wine for their drinking.\n',
#  'They put their hands to the good things that lay ready before them.\n',
#  '150 But when they had put away their desire for eating and drinking, the\n',
#  'suitors found their attention turned to other matters,\n',
#  'the song and the dance; for these things come at the end of the feasting.\n',
#  'A herald put the beautifully wrought lyre in the hands\n',
#  'of Phemios, who sang for the suitors, because they made him.\n',
#  '155 He played his lyre and struck up a fine song. Meanwhile\n',
#  'Telemachos talked to Athene of the gray eyes, leaning\n',
#  'his head close to hers, so that none of the others might hear him: ‘Dear\n',
#  'stranger, would you be scandalized at what I say to you?\n',
#  'This is all they think of, the lyre and the singing. Easy\n',
#  '160 for them, since without penalty they eat up the substance\n',
#  'of a man whose white bones lie out in the rain and fester\n',
#  'somewhere on the mainland, or roll in the wash of the breakers.\n',
#  'If they were ever to see him coming back to Ithaka\n',
#  'all the prayer of them all would be to be lighter on their feet\n',
#  '165 instead of to be richer men for gold and clothing.\n',
#  'As it is, he has died by an evil fate, and there is no comfort\n',
#  'left for us, not even though some one among mortals\n',
#  'tells us he will come back. His day of homecoming has perished.\n',
#  'But come now, tell me this and give me an accurate answer.\n',
#  '170 What man are you, and whence? Where is your city? Your parents?\n',
#  'What kind of ship did you come here on? And how did the sailors\n',
#  'bring you to Ithaka? What men do they claim that they are?\n',
#  'For I do not think you could have traveled on foot to this country.\n',
#  'And tell me this too, tell me truly, so that I may know it.\n',
#  "175 Are you here for the first time, or are you a friend of my father's from\n",
#  'abroad? Since many other men too used to come and visit\n',
#  'our house, in the days when he used to go about among people.’\n',
#  'Then in turn the goddess gray-eyed Athene answered him:\n',
#  '‘See, I will accurately answer all that you ask me.\n',
#  '180 I announce myself as Mentes, son of Anchialos\n',
#  'Athene disapproves of the suitors\n',
#  'the wise, and my lordship is over the oar-loving Taphians.\n',
#  'Now I have come in as you see, with my ship and companions\n',
#  'sailing over the wine-blue water to men of alien language,\n',
#  'to Temese, after bronze, and my cargo is gleaming iron.\n',
#  '185 And my ship stands near by, at the country, away from the city,\n',
#  'at the harbor, Rheithron, underneath wooded Neion.\n',
#  'Your father and I claim to be guest-friends by heredity\n',
#  'from far back, as you would know if you went to the aged hero\n',
#  'Laertes, who, they say, no longer comes to the city 190 now, but away by\n',
#  'himself on his own land leads a hard life\n',
#  'with an old woman to look after him, who serves him his victuals\n',
#  'and drink, at the times when the weariness has befallen his body\n',
#  'from making his toilsome way on the high ground of his vineyard.\n',
#  'Now I have come. They told me he was here in this country,\n',
#  '195 your father, I mean. But no. The gods are impeding his passage.\n',
#  'For no death on the land has befallen the great Odysseus,\n',
#  'but somewhere, alive on the wide sea, he is held captive,\n',
#  'on a sea-washed island, and savage men have him in their keeping, rough\n',
#  'men, who somehow keep him back, though he is unwilling.\n',
#  '200 Now, I will make you a prophecy, in the way the immortals\n',
#  'put it into my mind, and as I think it will come out,\n',
#  'though I am no prophet, nor do I know the ways of birds clearly.\n',
#  'He will not long be absent from the beloved land of his fathers,\n',
#  'even if the bonds that hold him are iron, but he will be thinking 205 of a\n',
#  'way to come back, since he is a man of many resources.\n',
#  'But come now tell me this and give me an accurate answer.\n',
#  'Are you, big as you are, the very child of Odysseus?\n',
#  'Indeed, you are strangely like about the head, the fine eyes,\n',
#  'as I remember; we used to meet so often together\n',
#  '210 before he went away to Troy, where others beside him\n',
#  'and the greatest of the Argives went in their hollow vessels.\n',
#  'Since that time I have not seen Odysseus nor has he seen me.’\n',
#  'Then the thoughtful Telemachos said to her in answer:\n',
#  '‘See, I will accurately answer all that you ask me.\n',
#  '215 My mother says indeed I am his. I for my part\n',
#  'do not know. Nobody really knows his own father.\n',
#  'But how I wish I could have been rather son to some fortunate\n',
#  'man, whom old age overtook among his possessions.\n',
#  'But of mortal men, that man has proved the most ill-fated\n',
#  'and Telemachos explains\n',
#  '220 whose son they say I am: since you question me on this matter.’\n',
#  'Then in turn the goddess gray-eyed Athene answered him:\n',
#  '‘The gods have not made yours a birth that will go nameless\n',
#  'hereafter, since Penelope bore such a son as you are.\n',
#  'But come now, tell me this and give me an accurate answer.\n',
#  '225 What feast is this, what gathering? How does it concern you?\n',
#  'A festival, or a wedding? Surely, no communal dinner.\n',
#  'How insolently they seem to swagger about in their feasting\n',
#  'all through the house. A serious man who came in among them\n',
#  'could well be scandalized, seeing much disgraceful behaviour.’\n',
#  '230 Then the thoughtful Telemachos said to her in answer: ‘My guest, since\n',
#  'indeed you are asking me all these questions, there was a time this house\n',
#  'was one that might be prosperous\n',
#  'and above reproach, when a certain man was here in his country.\n',
#  'But now the gods, with evil intention, have willed it otherwise,\n',
#  '235 and they have caused him to disappear, in a way no other\n',
#  'man has done. I should not have sorrowed so over his dying\n',
#  'if he had gone down among his companions in the land of the Trojans, or\n',
#  'in the arms of his friends, after he had wound up the fighting.\n',
#  'So all the Achaians would have heaped a grave mound over him,\n',
#  '240 and he would have won great fame for himself and his son hereafter.\n',
#  'But now ingloriously the stormwinds have caught and carried him\n',
#  'away, out of sight, out of knowledge, and he left pain and lamentation to\n',
#  'me. Nor is it for him alone that I grieve in my pain now.\n',
#  'No longer. For the gods have inflicted other cares on me.\n',
#  '245 For all the greatest men who have the power in the islands,\n',
#  'in Doulichion and Same and in wooded Zakynthos, and all who in rocky\n',
#  'Ithaka are holders of lordships,\n',
#  'all these are after my mother for marriage, and wear my house out.\n',
#  'And she does not refuse the hateful marriage, nor is she able\n',
#  '250 to make an end of the matter; and these eating up my substance\n',
#  'waste it away; and soon they will break me myself to pieces.’\n',
#  'Pallas Athene answered him in great indignation:\n',
#  '‘Oh, for shame. How great your need is now of the absent\n',
#  'Odysseus, who would lay his hands on these shameless suitors.\n',
#  '255 I wish he could come now to stand in the outer doorway\n',
#  'of his house, wearing a helmet and carrying shield and two spears, the way\n',
#  'he was the first time that ever I saw him\n',
#  'in our own house, drinking his wine and taking his pleasure,\n',
#  'Telemachos is to search for news of his father\n',
#  'coming in from Ephyre and from Ilos son of Mermeros.\n',
#  '260 Odysseus, you see, had gone there also in his swift ship\n',
#  'in search of a poison to kill men, so he might have it\n',
#  'to smear on his bronze-headed arrows, but Ilos would not\n',
#  'give him any, since he feared the gods who endure forever.\n',
#  'But my father did give it to him, so terribly did he love him.\n',
#  '265 I wish that such an Odysseus would come now among the suitors.\n',
#  'They all would find death was quick, and marriage a painful matter.\n',
#  "Yet all these are things that are lying upon the gods' knees:\n",
#  'whether he will come home to his vengeance, here in his household, or\n',
#  'whether he will not. Rather I will urge you to consider\n',
#  '270 some means by which you can force the suitors out of your household.\n',
#  'Come now, pay close attention to me and do as I tell you.\n',
#  'Tomorrow, summon the Achaian warriors into assembly\n',
#  'and publish your word to all, let the gods be your witnesses.\n',
#  'Tell the suitors to scatter and go back to their own holdings,\n',
#  '275 and as for your mother, if the spirit urges her to be married,\n',
#  'let her go back to the palace of her powerful father,\n',
#  'and they shall appoint the marriage and arrange for the wedding presents in\n',
#  'great amount, as ought to go with a beloved daughter.\n',
#  'But for yourself, I will counsel you shrewdly, and hope you will listen.\n',
#  '280 Fit out a ship with twenty oars, the best you can come by,\n',
#  'and go out to ask about your father who is so long absent,\n',
#  'on the chance some mortal man can tell you, who has listened to Rumor\n',
#  'sent by Zeus. She more than others spreads news among people.\n',
#  'First go to Pylos, and there question the great Nestor, 285 and from there\n',
#  'go over to Sparta to see fair-haired Menelaos,\n',
#  'since he came home last of all the bronze-armored Achaians.\n',
#  'Thus if you hear your father is alive and on his way home,\n',
#  'then, hard pressed though you are, you should still hold out for another\n',
#  'year. But if you hear he has died and lives no longer,\n',
#  '290 then make your way home to the beloved land of your fathers,\n',
#  'and pile up a tomb in his honor, and there make sacrifices\n',
#  'in great amount, as is fitting. And give your mother to a husband.\n',
#  'Then, after you have made an end of these matters, and done them, next\n',
#  'you must consider well in your heart and spirit\n',
#  '295 some means by which you can kill the suitors who are in your household,\n',
#  'by treachery or open attack. You should not go on\n',
#  'clinging to your childhood. You are no longer of an age to do that.\n',
#  'Enter Penelope\n',
#  'Or have you not heard what glory was won by great Orestes\n',
#  'among all mankind, when he killed the murderer of his father,\n',
#  '300 the treacherous Aigisthos, who had slain his famous father?\n',
#  'So you too, dear friend, since I can see you are big and splendid, be bold\n',
#  'also, so that in generations to come they will praise you.\n',
#  'But now it is time for me to go back down to my fast ship\n',
#  'and my companions, who must be very restless waiting\n',
#  '305 for me. Let all this be on your mind, and do as I tell you.’\n',
#  'Then the thoughtful Telemachos said to her in answer:\n',
#  '‘My guest, your words to me are very kind and considerate,\n',
#  'what any father would say to his son. I shall not forget them.\n',
#  'But come now, stay with me, eager though you are for your journey, 310 so\n',
#  'that you may first bathe and take your ease and, well rested\n',
#  'and happy in your heart, then go back to your ship with a present,\n',
#  'something prized, altogether fine, which will be your keepsake\n',
#  'from me, what loving guests and hosts bestow on each other.’\n',
#  'Then in turn the goddess gray-eyed Athene answered him:\n',
#  '315 ‘Do not detain me longer, eager as I am for my journey;\n',
#  'and that gift, whatever it is your dear heart bids you give me,\n',
#  'save it to give when I come next time, so I can take it\n',
#  'home; and choose a good one, and a fair exchange will befall you.’\n',
#  'So spoke the goddess gray-eyed Athene, and there she departed\n',
#  '320 like a bird soaring high in the air, but she left in his spirit\n',
#  'determination and courage, and he remembered his father\n',
#  'even more than he had before, and he guessed the meaning,\n',
#  'and his heart was full of wonder, for he thought it was a divinity.\n',
#  'At once he went over, a godlike man, to sit with the suitors.\n',
#  '325 The famous singer was singing to them, and they in silence sat listening.\n',
#  "He sang of the Achaians' bitter homecoming from Troy, which Pallas\n",
#  'Athene had inflicted upon them.\n',
#  'The daughter of Ikarios, circumspect Penelope, heard and heeded the\n',
#  'magical song from her upper chamber,\n',
#  '330 and descended the high staircase that was built in her palace,\n',
#  'not all alone, since two handmaidens went to attend her.\n',
#  'When she, shining among women, came near the suitors,\n',
#  'she stood by the pillar that supported the roof with its joinery, holding her\n',
#  'shining veil in front of her face, to shield it,\n',
#  '335 and a devoted attendant was stationed on either side of her.\n',
#  'All in tears she spoke then to the divine singer:\n',
#  'Penelope dismissed\n',
#  '‘Phemios, since you know many other actions of mortals\n',
#  "and gods, which can charm men's hearts and which the singers celebrate,\n",
#  'sit beside them and sing one of these, and let them in silence\n',
#  '340 go on drinking their wine, but leave off singing this sad\n',
#  'song, which always afflicts the dear heart deep inside me,\n',
#  'since the unforgettable sorrow comes to me, beyond others,\n',
#  'so dear a head do I long for whenever I am reminded\n',
#  'of my husband, whose fame goes wide through Hellas and midmost\n',
#  'Argos.’\n',
#  '345 Then the thoughtful Telemachos said to her in answer: ‘Why, my mother,\n',
#  'do you begrudge this excellent singer his pleasing himself as the thought\n',
#  'drives him? It is not the singers who are to blame, it must be Zeus is to\n',
#  'blame, who gives out\n',
#  'to men who eat bread, to each and all, the way he wills it.\n',
#  '350 There is nothing wrong in his singing the sad return of the Danaans.\n',
#  'People, surely, always give more applause to that song\n',
#  'which is the latest to circulate among the listeners.\n',
#  'So let your heart and let your spirit be hardened to listen.\n',
#  'Odysseus is not the only one who lost his homecoming\n',
#  '355 day at Troy. There were many others who perished, besides him.\n',
#  'Go therefore back in the house, and take up your own work,\n',
#  'the loom and the distaff, and see to it that your handmaidens\n',
#  'ply their work also; but the men must see to discussion,\n',
#  'all men, but I most of all. For mine is the power in this household.’\n',
#  '360 Penelope went back inside the house, in amazement, for she laid the\n',
#  'serious words of her son deep away in her spirit, and she went back to the\n',
#  'upper story with her attendant\n',
#  'women, and wept for Odysseus, her beloved husband, until\n',
#  'gray-eyed Athene cast sweet slumber over her eyelids.\n',
#  '365 But the suitors all through the shadowy halls were raising a tumult, and all\n',
#  'prayed for the privilege of lying beside her, until the thoughtful\n',
#  'Telemachos began speaking among them:\n',
#  '‘You suitors of my mother, overbearing in your rapacity,\n',
#  'now let us dine and take our pleasure, and let there be no\n',
#  '370 shouting, since it is a splendid thing to listen to a singer\n',
#  'who is such a singer as this man is, with a voice such as gods have.\n',
#  'Then tomorrow let us all go to the place of assembly,\n',
#  'and hold a session, where I will give you my forthright statement, that you\n',
#  'go out of my place and do your feasting elsewhere,\n',
#  'Telemachos and the suitors\n',
#  '375 eating up your own possessions, taking turns, household by household.\n',
#  'But if you decide it is more profitable and better\n',
#  "to go on, eating up one man's livelihood, without payment,\n",
#  'then spoil my house. I will cry out to the gods everlasting\n',
#  'in the hope that Zeus might somehow grant a reversal of fortunes.\n',
#  '380 Then you may perish in this house, with no payment given.’\n',
#  'So he spoke, and all of them bit their lips, in amazement\n',
#  'at Telemachos and the daring way he had spoken to them.\n',
#  'It was Antinoös the son of Eupeithes who answered: ‘Telemachos,\n',
#  'surely it must be the very gods who prompt you\n',
#  '385 to take the imperious line and speak so daringly to us.\n',
#  'I hope the son of Kronos never makes you our king in seagirt Ithaka.\n',
#  'Though to be sure that is your right by inheritance.’\n',
#  'Then the thoughtful Telemachos said to him in answer:\n',
#  '‘Antinoös, in case you wonder at what I am saying,\n',
#  '390 I would be willing to take that right, if Zeus should give it.\n',
#  'Do you think that is the worst thing that could happen to anyone?\n',
#  "It is not bad to be a king. Speedily the king's house\n",
#  'grows prosperous, and he himself has rank beyond others.\n',
#  'But in fact there are many other Achaian princes,\n',
#  '395 young and old, in seagirt Ithaka, any of whom might\n',
#  'hold this position, now that the great Odysseus has perished.\n',
#  'But I will be the absolute lord over my own household\n',
#  'and my servants, whom the great Odysseus won by force for me.’\n',
#  'Then in turn Eurymachos, son of Polybos, answered: 400 ‘Telemachos,\n',
#  'these matters, and which of the Achaians will be king in seagirt Ithaka, are\n',
#  "questions that lie on the gods' knees.\n",
#  'But I hope you keep your possessions and stay lord in your own household.\n',
#  'May the man never come who against your will and by force shall drive\n',
#  'you away from your holdings, while Ithaka is a place still lived in.\n',
#  '405 But, best of men, I wish to ask you about this stranger,\n',
#  'where he came from, what country he announces as being\n',
#  'his own, where lies his parent stock, and the fields of his fathers.\n',
#  'Has he brought some message from your father who is on his way here?\n',
#  'Or did he arrive pursuing some matter of his own business?\n',
#  '410 How suddenly he started away and vanished, and did not\n',
#  'wait to be made known. He was no mean man, by the look of him.’\n',
#  'Then the thoughtful Telemachos said to him in answer:\n',
#  'All retire\n',
#  "‘Eurymachos, there is no more hope of my father's homecoming.\n",
#  'I believe no messages any more, even should there be one,\n',
#  '415 nor pay attention to any prophecy, those times my mother\n',
#  'calls some diviner into the house and asks him questions.\n',
#  "This stranger is a friend of my father's. He comes from Taphos\n",
#  'and announces himself as Mentes, the son of Anchialos\n',
#  'the wise. And he is lord of the lovers of the oar, the Taphians.’\n',
#  '420 So spoke Telemachos, but in his heart he knew the immortal goddess. The\n',
#  'others, turning to the dance and the delightful song, took their pleasure\n',
#  'and awaited the coming of evening,\n',
#  'and the black evening came on as they were taking their pleasure.\n',
#  'Then they went home to go to bed, each to his own house,\n',
#  '425 but Telemachos went where, off the splendid courtyard, a lofty\n',
#  'bedchamber had been built for him, in a sheltered corner.\n',
#  'There he went to go to bed, his heart full of problems,\n',
#  'and devoted Eurykleia went with him, and carried the flaring torches. She\n',
#  'was the daughter of Ops the son of Peisenor, 430 and Laertes had bought\n',
#  'her long ago with his own possessions\n',
#  'when she was still in her first youth, and gave twenty oxen for her, and he\n',
#  'favored her in his house as much as his own devoted\n',
#  "wife, but never slept with her, for fear of his wife's anger.\n",
#  'She now carried the flaring torches for him. She loved him\n',
#  '435 more than the other maidservants, and had nursed him when he was little.\n',
#  'He opened the doors of the close-compacted bedchamber,\n',
#  'and sat down on the bed and took off his soft tunic\n',
#  'and put it into the hands of the sagacious old woman,\n',
#  'and she in turn folded the tunic, and took care of it for him,\n',
#  '440 and hung it up on a peg beside the corded bedstead.\n',
#  'Then she went out of the room, and pulled the door to behind her\n',
#  'with a silver hook, and with a strap drew home the door bolt.\n',
#  'There, all night long, wrapped in a soft sheepskin, he pondered\n',
#  'in his heart the journey that Pallas Athene had counseled.\n',
#  'BOOK II\n',
#  'Now when the young Dawn showed again with her rosy fingers, the dear\n',
#  'son of Odysseus stirred from where he was sleeping, and put on his\n',
#  'clothes, and slung a sharp sword over his shoulder.\n',
#  'Underneath his shining feet he bound the fair sandals\n',
#  '5 and went on his way from the chamber, like a god in presence.\n',
#  'He gave the word now to his clear-voiced heralds to summon by\n',
#  'proclamation to assembly the flowing-haired Achaians,\n',
#  'and the heralds made their cry, and the men were assembled swiftly.\n',
#  'Now when they were all assembled in one place together,\n',
#  '10 he went on his way to assembly, in his hands holding a bronze spear, not all\n',
#  'alone, but a pair of light-footed dogs went with him.\n',
#  'Athene drifted an enchantment of grace upon him.\n',
#  'and all the people had their eyes on him as he came forward.\n',
#  "He sat in his father's seat, and the elders made way before him.\n",
#  '15 The first now to speak to them was the hero Aigyptios, who was bent over\n',
#  'with age, and had seen things beyond number.\n',
#  'His own dear son, Antiphos the spearman, had gone off with godlike\n',
#  'Odysseus to Ilion, land of good horses, in the hollow ships, and now the\n',
#  'wild Cyclops had killed him 20 deep in his cave, and this was the last man\n',
#  'he had eaten.\n',
#  'He had three other sons. One of them, Eurynomos, went with the suitors;\n',
#  'the other two kept the estates of their fathers.\n',
#  'Issues in Ithaka\n',
#  'Even so, he could not forget the lost one. He grieved and mourned for him,\n',
#  'and it was in tears for him, now, that he stood forth and addressed them: 25\n',
#  '‘Hear me now, men of Ithaka, and the word I give you.\n',
#  'Never has there been an assembly of us or any session\n',
#  'since great Odysseus went away in the hollow vessels.\n',
#  'Now who has gathered us, in this way? What need has befallen which of\n',
#  'the younger men, or one of us who are older?\n',
#  '30 Has he been hearing some message about the return of the army which,\n',
#  'having heard it first, he could now explain to us?\n',
#  'Or has he some other public matter to set forth and argue?\n',
#  'I think he is a good man and useful. So may Zeus grant him good\n',
#  'accomplishment for whatever it is his mind desires.’\n',
#  '35 He spoke, and the dear son of Odysseus was glad for the omen, nor did he\n',
#  'remain seated long, his heart was for speaking, and he stood in the middle\n',
#  'of the assembly. The herald Peisenor, a man of deep discretion, put into\n',
#  'his hands the scepter.\n',
#  'First, in answer to the old man, he spoke and addressed him: 40 ‘Old sir,\n',
#  'the man is not far, but here; you yourself shall know him.\n',
#  'It is I who assembled the people. To me this grief comes closest.\n',
#  'Not that I heard some message about the return of the army, which, having\n',
#  'heard it first, I could now explain to you; nor have I some other public\n',
#  'matter to set forth and argue, 45 but my own need, the evil that has befallen\n',
#  'my household.\n',
#  'There are two evils. I have lost a noble father, one who\n',
#  'was king once over you here, and was kind to you like a father; and now\n',
#  'here is a greater evil, one which presently\n',
#  'will break up the whole house and destroy all my livelihood.\n',
#  '50 For my mother, against her will, is beset by suitors,\n',
#  'own sons to the men who are greatest hereabouts. These\n',
#  'shrink from making the journey to the house of her father Ikarios, so that\n',
#  'he might take bride gifts for his daughter and bestow her on the one he\n',
#  'wished, who came as his favorite; 55 rather, all their days, they come and\n',
#  'loiter in our house and sacrifice our oxen and our sheep and our fat goats\n',
#  'and make a holiday feast of it and drink the bright wine\n',
#  'recklessly. Most of our substance is wasted. We have no man here such as\n',
#  'Odysseus was, to drive this curse from the household.\n',
#  'Absence of Odysseus and persecution by the suitors\n',
#  '60 We ourselves are not the men to do it; we must be\n',
#  'weaklings in such a case, not men well seasoned in battle.\n',
#  'I would defend myself if the power were in me. No longer\n',
#  'are the things endurable that have been done, and beyond all decency my\n',
#  'house has been destroyed. Even you must be scandalized 65 and ashamed\n',
#  'before the neighboring men about us, the people who live around our land;\n',
#  "fear also the gods' anger,\n",
#  'lest they, astonished by evil actions, turn against you.\n',
#  'I supplicate you, by Zeus the Olympian and by Themis\n',
#  'who breaks up the assemblies of men and calls them in session: 70 let be,\n',
#  'my friends, and leave me alone with my bitter sorrow to waste away;\n',
#  'unless my noble father Odysseus\n',
#  'at some time in anger did evil to the strong-greaved Achaians, for which\n',
#  'angry with me in revenge you do me evil\n',
#  'in setting these on me. But for me it would be far better 75 for you to eat\n',
#  'away my treasures and eat my cattle.\n',
#  'If you were to eat them, there might be a recompense someday, for we\n',
#  'could go through all the settlement, with claims made public asking for our\n',
#  'goods again, until it was all regiven.\n',
#  'But now you are heaping me with troubles I cannot deal with.’\n',
#  '80 So he spoke in anger, and dashed to the ground the scepter in a stormburst\n',
#  'of tears; and pity held all the people.\n',
#  'Now all the rest were stricken to silence, none was so hardy as to answer,\n',
#  'angry word against word, the speech of Telemachos.\n',
#  'It was Antinoös alone spoke to him in answer:\n',
#  '85 ‘High-spoken intemperate Telemachos, what accusations you have made to\n',
#  'our shame, trying to turn opinion against us!\n',
#  'And yet you have no cause to blame the Achaian suitors,\n',
#  'but it is your own dear mother, and she is greatly resourceful.\n',
#  'And now it is the third year, and will be the fourth year presently, 90 since\n',
#  'she has been denying the desires of the Achaians.\n',
#  'For she holds out hope to all, and makes promises to each man, sending us\n',
#  'messages, but her mind has other intentions.\n',
#  "And here is another stratagem of her heart's devising.\n",
#  'She set up a great loom in her palace, and set to weaving 95 a web of\n',
#  'threads long and fine. Then she said to us:\n',
#  '“Young men, my suitors now that the great Odysseus has perished, wait,\n',
#  'though you are eager to marry me, until I finish\n',
#  'this web, so that my weaving will not be useless and wasted.\n',
#  'The charms and guile of Penelope\n',
#  'This is a shroud for the hero Laertes, for when the destructive 100 doom of\n',
#  'death which lays men low shall take him, lest any Achaian woman in this\n',
#  'neighborhood hold it against me\n',
#  'that a man of many conquests lies with no sheet to wind him.”\n',
#  'So she spoke, and the proud heart in us was persuaded.\n',
#  'Thereafter in the daytime she would weave at her great loom, 105 but in\n',
#  'the night she would have torches set by, and undo it.\n',
#  'So for three years she was secret in her design, convincing the Achaians,\n',
#  'but when the fourth year came with the seasons returning, one of her\n',
#  'women, who knew the whole of the story, told us, and we found her in the\n',
#  'act of undoing her glorious weaving.\n',
#  '110 So, against her will and by force, she had to finish it.\n',
#  'Now the suitors answer you thus, so that you yourself\n',
#  'may know it in your mind, and all the Achaians may know it: send your\n',
#  'mother back, and instruct her to be married\n',
#  'to any man her father desires and who pleases her also.\n',
#  '115 But if she continues to torment the sons of the Achaians, since she is so\n',
#  'dowered with the wisdom bestowed by Athene, to be expert in beautiful\n',
#  'work, to have good character\n',
#  'and cleverness, such as we are not told of, even of the ancient queens, the\n',
#  'fair-tressed Achaian women of times before us, 120 Tyro and Alkmene and\n',
#  'Mykene, wearer of garlands; for none of these knew thoughts so wise as\n',
#  'those Penelope knew; yet in this single matter she did not think rightly; so\n',
#  'long, I say, will your livelihood and possessions be eaten away, as long as\n',
#  'she keeps this purpose, one which the very 125 gods, I think, put into her\n',
#  'heart. She is winning a great name for herself, but for you she is causing\n',
#  'much loss of substance.\n',
#  'We will not go back to our own estates, nor will we go elsewhere until she\n',
#  'marries whichever Achaian man she fancies.’\n',
#  'Then the thoughtful Telemachos said to him in answer:\n',
#  '130 ‘Antinoös, I cannot thrust the mother who bore me,\n',
#  'who raised me, out of the house against her will. My father, alive or dead,\n',
#  'is elsewhere in the world. It will be hard to pay back Ikarios, if willingly I\n',
#  'dismiss my mother.\n',
#  'I will suffer some evil from her father, and the spirit will give me 135 more\n',
#  'yet, for my mother will call down her furies upon me as she goes out of the\n',
#  "house, and I shall have the people's resentment. I will not be the one to say\n",
#  'that word to her.\n',
#  'Favorable portents\n',
#  'But as for you, if your feeling is scandalized by my answer, go away from\n',
#  'my palace and do your feasting elsewhere,\n',
#  '140 eating up your own possessions, taking turns, household by household.\n',
#  'But if you decide it is more profitable and better\n',
#  "to go on, eating up one man's livelihood, without payment, then spoil my\n",
#  'house. I will cry out to the gods everlasting in the hope that Zeus might\n',
#  'somehow grant a reversal of fortunes.\n',
#  '145 Then you may perish in this house with no payment given.’\n',
#  'So spoke Telemachos, and for his sake Zeus of the wide brows\n',
#  'sent forth two eagles, soaring high from the peak of the mountain.\n',
#  'These for a while sailed on the stream of the wind together, wing and wing,\n',
#  'close together, wings spread wide. But when 150 they were over the\n',
#  'middle of the vociferous assembly,\n',
#  'they turned on each other suddenly in a thick shudder\n',
#  'of wings, and swooped over the heads of all, with eyes glaring and deadly,\n',
#  'and tore each other by neck and cheek with their talons, then sped away to\n',
#  'the right across the houses and city.\n',
#  '155 Then all were astounded at the birds, when their eyes saw them, and they\n',
#  'pondered in their hearts over what might come of it, and Halitherses,\n',
#  "Mastor's son, an aged warrior, spoke to them. He was far beyond the men\n",
#  'of his generation in understanding the meaning of birds and reading their\n',
#  'portents.\n',
#  '160 Now, in kind intention toward all, he spoke and addressed them: ‘Hear me\n',
#  'now, men of Ithaka, what I have to tell you;\n',
#  'but what I say will be mostly a warning to the suitors,\n',
#  'for a great disaster is wheeling down on them. Surely Odysseus will not be\n',
#  'long away from his family, but now, already,\n',
#  '165 is somewhere close by, working out the death and destruction of all these\n',
#  'men, and it will be an evil for many others\n',
#  'of us who inhabit sunny Ithaka. So, well beforehand,\n',
#  'let us think how we can make them stop, or better let them stop\n',
#  'themselves. It will soon be better for them if they do so.\n',
#  '170 I who foretell this am not untried, I know what I am saying.\n',
#  'Concerning him, I say that everything was accomplished\n',
#  'in the way I said it would be at the time the Argives took ship for Ilion, and\n',
#  'with them went resourceful Odysseus.\n',
#  'I said that after much suffering, with all his companions 175 lost, in the\n',
#  'twentieth year, not recognized by any,\n',
#  'he would come home. And now all this is being accomplished.’\n',
#  'The suitors refuse to leave\n',
#  'Then in turn Eurymachos, son of Polybos, answered: ‘Old sir, better go\n',
#  'home and prophesy to your children,\n',
#  'for fear they may suffer some evil to come. In these things 180 I can give a\n',
#  'much better interpretation than you can.\n',
#  "Many are the birds who under the sun's rays wander\n",
#  'the sky; not all of them mean anything; Odysseus\n',
#  'is dead, far away, and how I wish that you had died with him also. Then\n',
#  'you would not be announcing all these predictions, 185 nor would you so\n',
#  'stir up Telemachos, who is now angry,\n',
#  'looking for the gift for your own household, which he might give you.\n',
#  'But I will tell you straight out, and it will be a thing accomplished: if you,\n',
#  'who know much and have known it long, stir up a younger man, and by\n',
#  'talking him round with words encourage his anger, 190 then first of all, it\n',
#  'will be the worse for him; he will not on account of all these sayings be\n',
#  'able to accomplish anything; and on you, old sir, we shall lay a penalty,\n',
#  'and it will grieve your mind as you pay it, and that for you will be a great\n',
#  'sorrow.\n',
#  'I myself, before you all, will advise Telemachos.\n',
#  "195 Let him urge his mother to go back to her father's,\n",
#  'and they shall appoint the marriage and arrange for the wedding presents in\n',
#  'great amount, as ought to go with a beloved daughter.\n',
#  'For I think the sons of the Achaians will not give over\n',
#  'their harsh courtship, for in any case we fear no one,\n',
#  '200 and surely not Telemachos, for all he is so eloquent.\n',
#  'Nor do we care for any prophecy, which you, old sir,\n',
#  'may tell us, which will not happen, and will make you even more hated;\n',
#  'and his possessions will wretchedly be eaten away, there will not be\n',
#  'compensation, ever, while she makes the Achaians put off 205 marriage\n',
#  'with her, while we, awaiting this, all our days quarrel for the sake of her\n',
#  'excellence, nor ever go after others, whom any one of us might properly\n',
#  'marry.’\n',
#  'Then the thoughtful Telemachos said to him in answer:\n',
#  '‘Eurymachos, and all you others who are haughty suitors,\n',
#  '210 I no longer entreat you in these matters, nor speak about them, since by\n',
#  'now the gods know about this, as do all the Achaians.\n',
#  'But come now, grant me a swift ship, and twenty companions who can\n',
#  'convey me on a course from one place to another.\n',
#  'For I am going to Sparta and going to sandy Pylos\n',
#  '215 to ask about the homecoming of my father, who is long absent,\n',
#  'Telemachos requests a ship\n',
#  'on the chance of some mortal man telling me, or of hearing a Rumor sent\n',
#  'by Zeus. She more than others spreads news among people.\n',
#  'Then if I hear my father is alive and on his way home,\n',
#  'then, hard pressed though I be, I will still hold out for another 220 year.\n',
#  'But if I hear he has died and lives no longer,\n',
#  'then I will make my way home to the beloved land of my fathers, and pile\n',
#  'up a tomb in his honor, and there make sacrifices in great amount, as is\n',
#  'fitting. And give my mother to a husband.’\n',
#  'So he spoke, and sat down again, and among them rose up\n',
#  '225 Mentor, who once had been the companion of stately Odysseus, and\n',
#  'Odysseus, going on the ships, had turned over the household to the old\n',
#  'man, to keep it well, and so all should obey him.\n',
#  'He in kind intention now spoke forth and addressed them:\n',
#  '‘Hear me now, men of Ithaka, what I have to tell you.\n',
#  '230 No longer now let one who is a sceptered king be eager\n',
#  'to be gentle and kind, be one whose thought is schooled in justice, but let\n',
#  'him always rather be harsh, and act severely,\n',
#  'seeing the way no one of the people he was lord over\n',
#  'remembers godlike Odysseus, and he was kind, like a father.\n',
#  '235 Now it is not so much the proud suitors I resent\n',
#  "for doing their violent acts by their minds' evil devising; for they lay their\n",
#  'heads on the line when violently they eat up the house of Odysseus, who,\n',
#  'they say to themselves, will not come back; but now I hold it against you\n',
#  'other people, how you all\n',
#  '240 sit there in silence, and never with an assault of words try to check the\n',
#  'suitors, though they are so few, and you so many.’\n',
#  'Then Leokritos, son of Euenor, spoke forth against him: ‘Mentor,\n',
#  'reckless in words, wild in your wits, what a thing you have said, urging\n',
#  'them to stop us. It would be difficult 245 even with more men than these to\n',
#  'fight us over our feasting.\n',
#  'For even if Odysseus of Ithaka himself were to\n',
#  'come back, and find the haughty suitors feasting in his house, and be\n',
#  'urgent in his mind to drive them out of his palace, his wife would have no\n',
#  'joy of his coming, though she longs for it 250 greatly, but rather he would\n',
#  'meet an unworthy destiny\n',
#  'if he fought against too many. You have spoken to no purpose.\n',
#  'Come then, all people disperse now, each to his own holdings, and Mentor\n',
#  "and Halitherses will push forward this man's journey, since these from the\n",
#  'first have been his friends, as friends of his father.\n',
#  'End of assembly\n',
#  '255 But, I think, he will sit still for a long time, waiting for messages here in\n',
#  'Ithaka, and will never accomplish this voyage.’\n',
#  'So he spoke, and suddenly broke up the assembly,\n',
#  'and the people scattered and went their ways, each to his own house, while\n',
#  'the suitors went away into the house of godlike Odysseus.\n',
#  '260 But Telemachos, walking along the sea beach away from the others,\n',
#  'washed his hands in the gray salt water and prayed to Athene: ‘Hear me,\n',
#  'you who came yesterday, a god, into our house\n',
#  'and urged me on to go by ship out over the misty\n',
#  'face of the sea, to ask about the homecoming of my father 265 who is so\n',
#  'long absent: now all this is delayed by the Achaians and particularly the\n',
#  'suitors in their evil overconfidence.’\n',
#  'So he spoke in prayer, and from nearby Athene came to him\n',
#  'likening herself to Mentor in voice and appearance.\n',
#  'Now she spoke aloud to him and addressed him in winged words: 270\n',
# ...
#  'are ships in plenty here in seagirt Ithaka, both old and new ones,\n',
#  'Athene as Mentor advises Telemachos\n',
#  'and I will look them over for you to find out the best one, 295 and soon we\n',
#  'shall stow our gear and put out onto the wide sea.’\n',
#  'So spoke Athene, daughter of Zeus, nor did Telemachos\n',
#  'delay long after he had heard the voice of the goddess,\n',
#  'but went on his way to the house, the heart troubled within him.\n',
#  'He came upon the haughty suitors, there in his palace,\n',
#  '300 skinning goats and singeing fatted swine in the courtyard.\n',
#  'Antinoös, with a smile, came straight up to Telemachos,\n',
#  'and took him by the hand and spoke and named him, saying: ‘High-spoken\n',
#  'intemperate Telemachos, now let no other\n',
#  'evil be considered in your heart, neither action\n',
#  '305 nor word, but eat and drink with me, as you did in past time.\n',
#  'The Achaians will see to it that all these things are accomplished, the ship,\n',
#  'and chosen companions, so that you may the more quickly reach sacred\n',
#  'Pylos, after news about your proud father.’\n',
#  'Then the thoughtful Telemachos said to him in answer:\n',
#  '310 ‘Antinoös, there is no way for me to dine with you\n',
#  'against my will, and take my ease, when you are so insolent.\n',
#  'Is it not enough, you suitors, that in time past you ruined my great and\n',
#  'good possessions, when I was still in my childhood?\n',
#  'But now, when I am grown big, and by listening to others\n',
#  '315 can learn the truth, and the anger is steaming up inside me, I will\n',
#  'endeavor to visit evil destructions upon you,\n',
#  'either by going to Pylos, or remaining here in the district.\n',
#  'But I will go; that journey I speak of will not be made void; but as a\n',
#  'passenger; for I control no ship, not any\n',
#  '320 companions; this, I think, was the way you wished to have it.’\n',
#  "He spoke, and lightly drew away his hand from Antinoös'\n",
#  'hand, but the suitors about the house prepared their dinner, and in their\n',
#  'conversation they insulted him and mocked him, and thus would go the\n',
#  'word of one of the arrogant young men: 325 ‘Surely now Telemachos is\n',
#  'devising our murder.\n',
#  'Either he will bring some supporters from sandy Pylos,\n',
#  'or even from Sparta, now he is so terribly eager;\n',
#  'or perhaps his purpose is to go to Ephyre, that rich\n',
#  'corn land, so that thence he can bring back poisonous medicines 330 and\n',
#  'put them into our wine bowl, and so destroy all of us.’\n',
#  'And thus would speak another one of these arrogant young men:\n',
#  '‘Who knows whether, when he goes in a hollow ship, he also\n',
#  'The ship is ready\n',
#  'might perish straying far from his people, as did Odysseus?\n',
#  'Were this to happen, he would lighten all our work for us.\n',
#  "335 Then we could divide up his possessions, and give the house to this man's\n",
#  'mother to keep, and to the man who marries her.’\n',
#  "So they spoke, but he went down into his father's high-roofed\n",
#  'and wide storeroom, where gold and bronze were lying piled up, and\n',
#  'abundant clothing in the bins, and fragrant olive oil, 340 and in it jars of\n',
#  'wine, sweet to drink, aged,\n',
#  'were standing, keeping the unmixed divine drink inside them, lined up in\n',
#  'order close to the wall, for the day when Odysseus might come home even\n',
#  'after laboring through many hardships.\n',
#  'To close it there were double doors that fitted together\n',
#  '345 with two halves, and there by night and day was a woman\n',
#  'in charge who, with intelligent care, watched over all this, Eurykleia the\n',
#  'daughter of Ops the son of Peisenor.\n',
#  'Now Telemachos called her to the room, and spoke to her:\n',
#  '‘Dear nurse, come, draw me some sweet wine in the handled 350 jars,\n',
#  'choicest of all you have in your keeping, next after what you are saving for\n',
#  'the ill-fated man, the day when Zeus-sprung Odysseus might come home,\n',
#  'escaping death and its spirits.\n',
#  'Fill me twelve in all and fit them all with covers.\n',
#  'And pour me barley into bags stitched strongly, of leather.\n',
#  '355 Let me have twenty measures of the choice milled barley. You be the only\n',
#  'one that knows this. Let all be gathered together, for I will pick it up in the\n',
#  'evening, after my mother\n',
#  'climbs to her upper chamber and is ready for sleeping.\n',
#  'For I am going into Sparta and to sandy Pylos,\n',
#  "360 to ask after my dear father's homecoming, if I might hear something.’\n",
#  'So he spoke, and the dear nurse Eurykleia cried out,\n',
#  'and bitterly lamenting she addressed him in winged words: ‘Why, my\n',
#  'beloved child, has this intention come into\n',
#  'your mind? Why do you wish to wander over much country,\n',
#  '365 you, an only and loved son? Illustrious Odysseus\n',
#  'has perished far from his country in some outlandish region.\n',
#  'And these men will devise evils against you, on your returning, so you\n',
#  'shall die by guile, and they divide all that is yours.\n',
#  'No, but stay here and guard your possessions. It is not right 370 for you to\n',
#  'wander and suffer hardships on the barren wide sea.’\n',
#  'Then the thoughtful Telemachos said to her in answer:\n',
#  'Preparations for sailing\n',
#  "‘Do not fear, nurse. This plan was not made without a god's will.\n",
#  'But swear to tell my beloved mother nothing about this\n',
#  'until the eleventh day has come or the twelfth hereafter, 375 or until she\n',
#  'misses me herself or hears I am absent,\n',
#  'so that she may not ruin her lovely skin with weeping.’\n',
#  'So he spoke, and the old woman swore to the gods a great oath,\n',
#  'and after she had sworn to it and completed the oath taking, she drew the\n',
#  'wine in the handled jars at once thereafter\n',
#  '380 and poured his barley into bags stitched strongly of leather, but\n',
#  'Telemachos went back into the house and joined the suitors.\n',
#  'Now the gray-eyed goddess Athene thought what to do next.\n',
#  'In the likeness of Telemachos she went all through the city and, standing\n',
#  'beside each man as she came to him, told them 385 all to assemble beside\n',
#  'the fast ship in the evening.\n',
#  'Then she asked Noëmon, the glorious son of Phronios, for a fast ship. And\n',
#  'he with good will promised it to her.\n',
#  'And the sun set, and all the journeying ways were darkened.\n',
#  'Now she drew the fast ship down to the sea, and in her\n',
#  '390 stowed all the running gear that strong-benched vessels carry.\n',
#  'She set it at the edge of the harbor, and around her the good companions\n',
#  'thronged and were assembled and the goddess urged on each man.\n',
#  'Now the gray-eyed goddess Athene thought what to do next.\n',
#  'She went on her way, into the house of godlike Odysseus,\n',
#  '395 and there she drifted a sweet slumber over the suitors,\n',
#  'and struck them as they drank, and knocked the goblets out of their hands,\n',
#  'and they went to sleep in the city, nor did any one sit long, after sleep was\n',
#  'fallen upon his eyelids.\n',
#  'Afterward gray-eyed Athene spoke to Telemachos\n',
#  '400 when she had called him out from the well-established palace, likening\n',
#  'herself to Mentor in voice and appearance:\n',
#  '‘Telemachos, already now your strong-greaved companions\n',
#  'are sitting at the oars, and waiting for you to set forth.\n',
#  'So let us go, and not delay our voyaging longer.’\n',
#  '405 So spoke Pallas Athene, and she led the way swiftly, and the man\n',
#  "followed behind her walking in the god's footsteps.\n",
#  'But when they had come down to the sea, and where the ship was, they\n',
#  'found the flowing-haired companions there by the seashore.\n',
#  'Now the hallowed prince, Telemachos, spoke his word to them: 410 ‘Here,\n',
#  'friends, let us carry the provisions. They are all ready\n',
#  'The sailing\n',
#  'and stacked in the hall. But my mother has been told nothing of this, nor\n',
#  'the rest of the serving women. Only one knows the story.’\n',
#  'So he spoke and led the way, and the rest went with him.\n',
#  'They all carried the provisions down, and stowed them in the strong-\n',
#  'benched 415 vessel, in the way the dear son of Odysseus directed them.\n',
#  'Telemachos went aboard the ship, but Athene went first\n',
#  'and took her place in the stern of the ship, and close beside her Telemachos\n',
#  'took his place. The men cast off the stern cables and themselves also went\n',
#  'aboard and sat to the oarlocks.\n',
#  '420 The goddess gray-eyed Athene sent them a favoring stern wind, strong\n',
#  'Zephyros, who murmured over the wine-blue water.\n',
#  'Telemachos then gave the sign and urged his companions\n',
#  'to lay hold of the tackle, and they listened to his urging and, raising the\n',
#  'mast pole made of fir, they set it upright 425 in the hollow hole in the box,\n',
#  'and made it fast with forestays, and with halyards strongly twisted of\n',
#  'leather pulled up the white sails.\n',
#  'The wind blew into the middle of the sail, and at the cutwater a blue wave\n',
#  'rose and sang strongly as the ship went onward.\n',
#  'She ran swiftly, cutting across the swell her pathway.\n',
#  '430 When they had made fast the running gear all along the black ship, then\n',
#  'they set up mixing bowls, filling them brimful\n',
#  'with wine, and poured to the gods immortal and everlasting but beyond all\n',
#  "other gods they poured to Zeus' gray-eyed daughter.\n",
#  'All night long and into the dawn she ran on her journey.\n',
#  'BOOK III\n',
#  'Helios, leaving behind the lovely standing waters, rose up\n',
#  'into the brazen sky to shine upon the immortals\n',
#  'and also on mortal men across the grain-giving farmland.\n',
#  "They came to Pylos, Neleus' strong-founded citadel,\n",
#  '5 where the people on the shore of the sea were making sacrifice\n',
#  'of bulls who were all black to the dark-haired Earthshaker.\n',
#  'There were nine settlements of them, and in each five hundred\n',
#  'holdings, and from each of these nine bulls were provided.\n',
#  'Now as these tasted the entrails, and burned, for the god, the thigh bones,\n',
#  '10 these others put straight in, and on the balanced ship took off the sails,\n',
#  'and stowed them, and moored her in, and themselves landed.\n',
#  'Telemachos stepped out of the ship, but Athene went first,\n',
#  'and it was the gray-eyed goddess Athene who first spoke to him:\n',
#  '‘Telemachos, here is no more need at all of modesty;\n',
#  '15 for this was why you sailed on the open sea, to find news\n',
#  'of your father, what soil covers him, what fate he has met with.\n',
#  'So come now, go straight up to Nestor, breaker of horses,\n',
#  'for we know what intelligence is hidden inside him.\n',
#  'You yourself must entreat him to speak the whole truth to you.\n',
#  '20 He will not tell you any falsehood; he is too thoughtful.’\n',
#  'Then the thoughtful Telemachos said to her in answer:\n',
#  '‘Mentor, how shall I go up to him, how close with him?\n',
#  'I have no experience in close discourse. There is\n',
#  'embarrassment for a young man who must question his elder.’\n',
#  'Entertainment by Nestor\n',
#  '25 Then in turn the gray-eyed goddess Athene answered him:\n',
#  '‘Telemachos, some of it you yourself will see in your own heart, and some\n',
#  'the divinity will put in your mind. I do not\n',
#  "think you could have been born and reared without the gods' will.’\n",
#  'So spoke Pallas Athene, and she led the way swiftly,\n',
#  "30 and the man followed behind her walking in the god's footsteps.\n",
#  'They came to where the men of Pylos were gathered in session,\n',
#  'where Nestor was sitting with his sons, and companions about him were\n',
#  'arranging the feast, and roasting the meat, and spitting more portions.\n',
#  'These men, when they sighted the strangers, all came down together 35\n',
#  'and gave them greeting with their hands and offered them places.\n',
#  'First Peisistratos, son of Nestor, came close up to them and took them both\n',
#  'by the hands, and seated them at the feasting on soft rugs of fleece there on\n',
#  'the sand of the seashore\n',
#  'next to his brother Thrasymedes and next to his father.\n',
#  '40 He gave them portions of the vitals, and poured wine for them\n',
#  'in a golden cup, and spoke a word to both of them, pledging\n',
#  'Pallas Athene, who is daughter of Zeus of the aegis:\n',
#  '‘My guest, make your prayer now to the lord Poseidon,\n',
#  'for his is the festival you have come to on your arrival;\n',
#  '45 but when you have poured to him and prayed, according to custom, then\n',
#  'give this man also a cup of the sweet wine, so that\n',
#  'he too can pour, for I think he also will make his prayer\n',
#  'to the immortals. All men need the gods. But this one\n',
#  'is a younger man than you, and of the same age as I am.\n',
#  '50 This is why I am first giving you the golden goblet.’\n',
#  'So he spoke, and put in her hand the cup of sweet wine,\n',
#  'and Athene was happy at the thoughtfulness of a just man,\n',
#  'because it was to her he first gave the golden goblet.\n',
#  'Immediately she made her prayer to the lord Poseidon:\n',
#  '55 ‘Hear us, Poseidon, who circle the earth, and do not begrudge us the\n',
#  'accomplishment of all these actions for which we pray you.\n',
#  'First of all to Nestor and to his sons grant glory,\n',
#  'and then on all the rest of the Pylians besides confer\n',
#  'gracious recompense in return for this grand hecatomb,\n',
#  '60 and yet again grant that Telemachos and I go back\n',
#  'with that business done for which we came this way in our black ship.’\n',
#  'She spoke in prayer, but herself was bringing it all to completion.\n',
#  'Telemachos asks after Odysseus\n',
#  'Next she gave Telemachos the fine two-handled goblet,\n',
#  'and the dear son of Odysseus prayed in the way that she had.\n',
#  '65 When they had roasted and taken off the spits the outer\n',
#  'meats, dividing shares they held their communal high feast.\n',
#  'But when they had put aside their desire for eating and drinking, first to\n',
#  'speak was the Gerenian horseman, Nestor: ‘Now is a better time to\n',
#  'interrogate our guests and ask\n',
#  '70 them who they are, now they have had the pleasure of eating.\n',
#  'Strangers, who are you? From where do you come sailing over the watery\n',
#  'ways? Is it on some business, or are you recklessly roving\n',
#  'as pirates do, when they sail on the salt sea and venture\n',
#  'their lives as they wander, bringing evil to alien people?’\n',
#  '75 Then the thoughtful Telemachos said to him in answer,\n',
#  'taking courage, for Athene herself had put that courage\n',
#  'in his heart, so that he might ask after his absent father,\n',
#  'and so that among people he might win a good reputation:\n',
#  "‘O Nestor, Neleus' son, great glory of the Achaians,\n",
#  '80 you ask us where we come from. Therefore I will tell you.\n',
#  'We come from Ithaka under the mountain Neion. This is\n',
#  'a private matter, no public business, of which I tell you.\n',
#  'I follow the wide fame of my father, on the chance of hearing\n',
#  'of the great patient-hearted Odysseus, the man they say once\n',
#  '85 fought beside you and helped sack the city of the Trojans.\n',
#  'For we have been told about all the other men who once fought\n',
#  'the Trojans, how each one of them perished in sad destruction,\n',
#  "but the son of Kronos has made this man's death one that none knows.\n",
#  'There is no man who can plainly tell us when he perished,\n',
#  '90 whether he was killed on the mainland by men embattled\n',
#  'or on the open sea in the billows of Amphitrite.\n',
#  'That is why I come to your knees now, in case you might wish\n',
#  'to tell me of his dismal destruction, whether you saw it\n',
#  'perhaps with your own eyes, or heard the tale from another\n',
#  '95 who wandered too. His mother bore this man to be wretched.\n',
#  'Do not soften it because you pity me and are sorry\n',
#  'for me, but fairly tell me all that your eyes have witnessed.\n',
#  'I implore you, if ever noble Odysseus, my father,\n',
#  ...]

# %% [markdown]
# ## Path A: Controlled normalization
#
# A transparent, "manual," normalization using regex.
#
# #### Output file: "Odyssey_Lattimore_Normalized_v1.txt"

# %%
# Step 2: Normalize the text
import re

# Removing numeral digits
def remove_digits(text):
    """
    Remove all digits from a string.
    """
    if isinstance(text, list):
        # If text is a list, apply the function to each element
        return [remove_digits(line) for line in text]
    else:
        # Remove digits using regex
        return re.sub(r'\d', '', text)

# Removing diacritics, macrons, circumflex, dieresis/umlaut, etc
def normalize_text(text):
    """
    Normalize text by replacing diacritics with their base characters.
    """
    # Dictionary mapping diacritics to their base characters
    replacements = {
        # Dieresis/umlaut characters
        'ä': 'a', 'ë': 'e', 'ï': 'i', 'ö': 'o', 'ü': 'u',
        'Ä': 'A', 'Ë': 'E', 'Ï': 'I', 'Ö': 'O', 'Ü': 'U',
        
        # Circumflex characters
        'â': 'a', 'ê': 'e', 'î': 'i', 'ô': 'o', 'û': 'u',
        'Â': 'A', 'Ê': 'E', 'Î': 'I', 'Ô': 'O', 'Û': 'U',
        
        # Macron characters
        'ā': 'a', 'ē': 'e', 'ī': 'i', 'ō': 'o', 'ū': 'u',
        'Ā': 'A', 'Ē': 'E', 'Ī': 'I', 'Ō': 'O', 'Ū': 'U',
        
        # Even more diacritics
        # Acute
        'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u',
        # Grave
        'à': 'a', 'è': 'e', 'ì': 'i', 'ò': 'o', 'ù': 'u',
    }
    
    # Replacement time!
    for original, replacement in replacements.items():
        text = text.replace(original, replacement)
    
    return text

# %%
def extract_and_compare_section(text_to_compare, start_phrase, end_phrase):
    """
    Extract a section of text between two phrases and compare before/after normalization.
    """
    # Find the start and end indices
    start_index = text_to_compare.find(start_phrase)
    if start_index == -1:
        return "Start phrase not found in text"
    
    # Add the length of the start phrase to get to the end of it
    start_index += len(start_phrase)
    
    # Find the end phrase starting from after the start phrase
    end_index = text_to_compare.find(end_phrase, start_index)
    if end_index == -1:
        return "End phrase not found after the start phrase"
    
    # Extract the section
    section = text_to_compare[start_index:end_index]
    
    # Normalize the section
    normalized_section = normalize_text(section)
    
    # Create a comparison output
    result = "Original section:\n"
    result += section
    result += "\n\nNormalized section:\n"
    result += normalized_section
    
    return result

# The before-normalization text
text_to_compare = "".join(new_lines)

# Extract and compare the section
comparison = extract_and_compare_section(
    text_to_compare,
    "then, whether we should unharness their fast horses,",
    "So he spoke, and the man hurried through the hall, bestirring"
)

print(comparison)
# Out:
# Original section:
#
# or send them on to somebody else, who can entertain them.’
# 30 Then, deeply vexed, fair-haired Menelaos answered him:
# Eteoneus, son of Boëthoös, you were never a fool before, but now you are
# babbling nonsense, as a child
# would do. Surely we two have eaten much hospitality
# from other men before we came back here. May Zeus only
# 35 make an end of such misery hereafter. Unharness
# the strangers' horses then, and bring the men here to be feasted.’
#
#
# Normalized section:
#
# or send them on to somebody else, who can entertain them.’
# 30 Then, deeply vexed, fair-haired Menelaos answered him:
# Eteoneus, son of Boethoos, you were never a fool before, but now you are
# babbling nonsense, as a child
# would do. Surely we two have eaten much hospitality
# from other men before we came back here. May Zeus only
# 35 make an end of such misery hereafter. Unharness
# the strangers' horses then, and bring the men here to be feasted.’

# %% [markdown]
# **The comparison above shows that the  fuction  is working as expected——no dieresis/umlaut!**
#
# Thus, we proceed to normalize.

# %%
# Apply the normalization to the text
text = remove_digits(text)
text = normalize_text(text)

# %%
import re

text = re.sub(r'\n+', ' ', text)
text
# Out:
# "BOOK I Tell me, Muse, of the man of many ways, who was driven far journeys, after he had sacked Troy's sacred citadel. Many were they whose cities he saw, whose minds he learned of, many the pains he suffered in his spirit on the wide sea,  struggling for his own life and the homecoming of his companions. Even so he could not save his companions, hard though he strove to; they were destroyed by their own wild recklessness, fools, who devoured the oxen of Helios, the Sun God, and he took away the day of their homecoming. From some point  here, goddess, daughter of Zeus, speak, and begin our story. Then all the others, as many as fled sheer destruction, were at home now, having escaped the sea and the fighting. This one alone, longing for his wife and his homecoming, was detained by the queenly nymph Kalypso, bright among goddesses,  in her hollowed caverns, desiring that he should be her husband. But when in the circling of the years that very year came in which the gods had spun for him his time of homecoming to Ithaka, not even then was he free of his trials nor among his own people. But all the gods pitied him  except Poseidon; he remained relentlessly angry with godlike Odysseus, until his return to his own country. But Poseidon was gone now to visit the far Aithiopians, Aithiopians, most distant of men, who live divided, some at the setting of Hyperion, some at his rising, The council of the gods  to receive a hecatomb of bulls and rams. There he sat at the feast and took his pleasure. Meanwhile the other Olympian gods were gathered together in the halls of Zeus. First among them to speak was the father of gods and mortals, for he was thinking in his heart of stately Aigisthos,  whom Orestes, Agamemnon's far-famed son, had murdered. Remembering him he spoke now before the immortals: ‘Oh for shame, how the mortals put the blame upon us gods, for they say evils come from us, but it is they, rather, who by their own recklessness win sorrow beyond what is given,  as now lately, beyond what was given, Aigisthos married the wife of Atreus' son, and murdered him on his homecoming, though he knew it was sheer destruction, for we ourselves had told him, sending Hermes, the mighty watcher, Argeiphontes, not to kill the man, nor court his lady for marriage;  for vengeance would come on him from Orestes, son of Atreides, whenever he came of age and longed for his own country. So Hermes told him, but for all his kind intention he could not persuade the mind of Aigisthos. And now he has paid for everything.' Then in turn the goddess gray-eyed Athene answered him:  ‘Son of Kronos, our father, O lordliest of the mighty, Aigisthos indeed has been struck down in a death well merited. Let any other man who does thus perish as he did. But the heart in me is torn for the sake of wise Odysseus, unhappy man, who still, far from his friends, is suffering  griefs, on the sea-washed island, the navel of all the waters, a wooded island, and there a goddess has made her dwelling place; she is daughter of malignant Atlas, who has discovered all the depths of the sea, and himself sustains the towering columns which bracket earth and sky and hold them together.  This is his daughter; she detains the grieving, unhappy man, and ever with soft and flattering words she works to charm him to forget Ithaka; and yet Odysseus, straining to get sight of the very smoke uprising from his own country, longs to die. But you, Olympian,  the heart in you is heedless of him. Did not Odysseus do you grace by the ships of the Argives, making sacrifice in wide Troy? Why, Zeus, are you now so harsh with him?’ Then in turn Zeus who gathers the clouds made answer: and the wrath of Poseidon ‘My child, what sort of word escaped your teeth's barrier?  How could I forget Odysseus the godlike, he who is beyond all other men in mind, and who beyond others has given sacrifice to the gods, who hold wide heaven? It is the Earth Encircler Poseidon who, ever relentless, nurses a grudg ...

# %%
# Create output directory if it doesn't exist
import os
output_filepath = f"/Users/debr/odysseys_en/normalized_txts/Odyssey_{translator}_Normalized_v1.txt"
os.makedirs(os.path.dirname(output_filepath), exist_ok=True)

# Write to a new file 
with open(output_filepath, 'w') as file:
    file.writelines(text)

# %% [markdown]
# ## Path B: Broad-brush method normalization
#
# An indiscriminate approach to normalization using the unicodedata Python module.
# Fast an efficient but we don't control all the changes as method A.
#
# #### Output file: "Odyssey_Green_Normalized_v2.txt"

# %%
import os
import unicodedata
import re

def normalize_text_unicodedata(text):
    """
    Normalize text using Python's unicodedata module.
    This handles all diacritics in a standardized way.
    """
    # NFD decomposes characters into base characters and combining marks, ie, "é" -> "e" + "◌́" 
    # Then we filter out the combining marks (category starts with 'M')
    return ''.join(c for c in unicodedata.normalize('NFD', text)
                  if not unicodedata.category(c).startswith('M'))

def remove_digits(text):
    """
    Remove all digits from a string.
    """
    if isinstance(text, list):
        # If text is a list, apply the function to each element
        return [remove_digits(line) for line in text]
    else:
        # Remove digits using regex
        return re.sub(r'\d', '', text)

# Read clean text again
filepath = f"/Users/debr/odysseys_en/cleaned_txts/Odyssey_{translator}_Cleaned.txt"

with open(filepath, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Filter out the book headers
#book_headers = [f'Book {i}' for i in range(1, 25)]
#filtered_lines = [line for line in lines if line.strip() not in book_headers]
filtered_lines = [line for line in lines if line.strip() != '']

# Normalize each line
normalized_lines = [normalize_text_unicodedata(line) for line in filtered_lines]

# Remove digits
final_lines = remove_digits(normalized_lines)

text_uni = "".join(final_lines)

# %%
# Replace consecutive empty lines with a single newline
text_uni[:1000]
# Out:
# "BOOK I\nTell me, Muse, of the man of many ways, who was driven\nfar journeys, after he had sacked Troy's sacred citadel.\nMany were they whose cities he saw, whose minds he learned of,\nmany the pains he suffered in his spirit on the wide sea,\n struggling for his own life and the homecoming of his companions.\nEven so he could not save his companions, hard though\nhe strove to; they were destroyed by their own wild recklessness, fools,\nwho devoured the oxen of Helios, the Sun God, and he took away the day\nof their homecoming. From some point\n here, goddess, daughter of Zeus, speak, and begin our story.\nThen all the others, as many as fled sheer destruction, were at home\nnow, having escaped the sea and the fighting.\nThis one alone, longing for his wife and his homecoming,\nwas detained by the queenly nymph Kalypso, bright among goddesses, \nin her hollowed caverns, desiring that he should be her husband.\nBut when in the circling of the years that very year came in which the gods\nhad spun for hi"

# %%
# Create output directory if it doesn't exist
output_filepath = f"/Users/debr/odysseys_en/normalized_txts/Odyssey_{translator}_Normalized_v2.txt"
os.makedirs(os.path.dirname(output_filepath), exist_ok=True)

# Write to a new file
with open(output_filepath, 'w', encoding='utf-8') as file:
    file.writelines(text_uni)

print(f"Normalization complete. File saved to: {output_filepath}")
# Out:
# Normalization complete. File saved to: /Users/debr/odysseys_en/normalized_txts/Odyssey_Lattimore_Normalized_v2.txt

# %%
print("length after controlled normalization:", len(text))
print("Length after broad-brush normalization:", len(text_uni))
# Out:
# length after controlled normalization: 735197
# Length after broad-brush normalization: 735199

# %%
# count new lines "\n"
def count_line_breaks(text):
    line_breaks = text.count('\n')
    return line_breaks

# Usage example
lines_my_norm = count_line_breaks(text)
lines_unicode = count_line_breaks(text_uni)
print(f"Number of lines in my custom normalization: {lines_my_norm}")
print(f"Number of lines with unicode normalization: {lines_unicode}")
# Out:
# Number of lines in my custom normalization: 0
# Number of lines with unicode normalization: 12367
