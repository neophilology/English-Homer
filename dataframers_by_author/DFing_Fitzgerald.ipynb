# %% [markdown]
# # Dataframer: Fitzgerald's Odyssey to Pandas DF
#
# ### [—————————————pipeline—————————————]
# ### »——raw—»—clean—»—normalize—»—DATAFRAME——»
#
# Here are some transformation and frequencies for future exploratory analysis of Green's Odyssey.
#
# Columns: author, year, title, book_num, text, num_lines, num_sentences, num_words,

# %%
# library imports
import os

import numpy as np
import pandas as pd

import re
import nltk

# %%
# Display options
pd.set_option("display.max_colwidth", None)  # Prevent truncation of long values
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.expand_frame_repr", False)  # Prevent wrapping in DataFrames

# %%
# Visualization libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/Users/debr/English-Homer') 
import bard_visualization as viz# This will apply the visualization settings
from bard_visualization import color_palette 
sys.path.append('/Users/debr/English-Homer/functions') 
import e_nlp as e
# Out:
# Functions for NLP are live! use e.<function> to call them.
# Downloading NLTK resources...
# Download complete.
# Stopwords customized:
#   Added: {'four', 'n', 'three', 'seven', 'six', 'one', "'", 'ten', "'and", 'two', 'nine', 'eight', 'five'}
#   Removed: {''}
#   Total stopwords: 211
# Punctuation customized:
#   Keeping: {'', '-'}
#   Additional removals: {'“', '—', '’', '…', '‘', '\\', '”', '-'}
#   Punctuation to be removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~—‘’“”…
# [nltk_data] Downloading package punkt_tab to /Users/debr/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# TO UPDATE
translator = "Fitzgerald"
book_breaker = "BOOK"

# Check Paths
filepath = f"/Users/debr/odysseys_en/Normalized_txts/Odyssey_{translator}_Normalized.txt"
output_path = f"/Users/debr/English-Homer/dataframers_by_author/{translator}_DFed/"
os.makedirs(os.path.dirname(output_path), exist_ok=True)
output_path_plots = f"{output_path}/plots/"
os.makedirs(os.path.dirname(output_path_plots), exist_ok=True)

# READING FILE TO extracted_lines
with open(filepath, 'r') as file:
    extracted_lines = file.readlines()

text = "".join(extracted_lines)

# %%
# Function to split the text into books

#books = string_into_books(text, book_breaker)
books = e.list_into_books(extracted_lines, book_breaker)

# Verify the results
print(f"Found {len(books)} books")
for i, book in enumerate(books):
    print(f"Book {i+1} starts with: {book[0]}")
    print(f"Book {i+1} has {len(book)} lines")
# Out:
# Found 24 books
# Book 1 starts with: Sing in me, Muse, and through me tell the story
#
# Book 1 has 500 lines
# Book 2 starts with: When primal Dawn spread on the eastern sky
#
# Book 2 has 462 lines
# Book 3 starts with: The sun rose on the flawless brimming sea
#
# Book 3 has 542 lines
# Book 4 starts with: By vales and sharp ravines in Lakedaimon
#
# Book 4 has 901 lines
# Book 5 starts with: Dawn came up from the couch of her reclining,
#
# Book 5 has 519 lines
# Book 6 starts with: Far gone in weariness, in oblivion,
#
# Book 6 has 351 lines
# Book 7 starts with: As Lord Odysseus prayed there in the grove
#
# Book 7 has 371 lines
# Book 8 starts with: Under the opening fingers of the dawn
#
# Book 8 has 626 lines
# Book 9 starts with: Now this was the reply Odysseus made:
#
# Book 9 has 618 lines
# Book 10 starts with: We made our landfall on Aiolia Island,
#
# Book 10 has 635 lines
# Book 11 starts with: We bore down on the ship at the sea’s edge
#
# Book 11 has 759 lines
# Book 12 starts with: The ship sailed on, out of the Ocean Stream,
#
# Book 12 has 580 lines
# Book 13 starts with: He ended it, and no one stirred or sighed
#
# Book 13 has 551 lines
# Book 14 starts with: He went up from the cove through wooded ground,
#
# Book 14 has 631 lines
# Book 15 starts with: South into Lakedaimon
#
# Book 15 has 677 lines
# Book 16 starts with: But there were two men in the mountain hut—
#
# Book 16 has 592 lines
# Book 17 starts with: When the young Dawn came bright into the East
#
# Book 17 has 794 lines
# Book 18 starts with: Now a true scavenger came in—a public tramp
#
# Book 18 has 520 lines
# Book 19 starts with: Now by Athena’s side in the quiet hall
#
# Book 19 has 699 lines
# Book 20 starts with: Outside in the entry way he made his bed—
#
# Book 20 has 439 lines
# Book 21 starts with: Upon Penelope, most worn in love and thought,
#
# Book 21 has 500 lines
# Book 22 starts with: Now shrugging off his rags the wiliest fighter of the islands leapt and
#
# Book 22 has 566 lines
# Book 23 starts with: The old nurse went upstairs exulting,
#
# Book 23 has 422 lines
# Book 24 starts with: Meanwhile the suitors’ ghosts were called away
#
# Book 24 has 614 lines

# %%
# Books (lists) into DataFrame
df = e.book_into_df(f"{translator}", "1961", "The Odyssey", books)

# Apply functions & add new columns
df['num_lines'] = df['text'].apply(e.count_lines)
df['num_sentences'] = df['text'].apply(e.count_sentences)
df['num_words'] = df['text'].apply(e.count_words)

# %%
# Initialize the pipeline
nlp = e.NLPPipeline(language='english')

# Customize stopwords
nlp.customize_stopwords(
    include={'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten',
             "'", 'n', "'and",},
    exclude={''}
)
# Customize punctuation
nlp.customize_punctuation(
    keep={'-', ""},  # Keep hyphens and apostrophes
    remove={r'…', '—','”','’','“', '‘', '-', '\\'}  # Additional characters to remove
)

# Process with default pipeline (lowercase -> tokenize -> remove punctuation -> remove stopwords)
df = nlp.process_dataframe(df, 'text', 'tokens')
df['num_tokens'] = df['tokens'].map(len)
# Out:
# Stopwords customized:
#   Added: {'four', 'n', 'three', 'seven', 'six', 'one', "'", 'ten', 'eight', 'two', 'nine', "'and", 'five'}
#   Removed: {''}
#   Total stopwords: 211
# Punctuation customized:
#   Keeping: {'', '-'}
#   Additional removals: {'—', '“', '’', '…', '‘', '\\', '”', '-'}
#   Punctuation to be removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~—‘’“”…

# %%
print('Type:', type(df['text'][0]))
print('Lenght:',len(df['text'][0]))
print(df['text'][:6])
# Out:
# Type: <class 'list'>
# Lenght: 500
# 0                                                                                                                                                                                                                                                                                                                       [Sing in me, Muse, and through me tell the story \n, of that man skilled in all ways of contending, \n, the wanderer, harried for years on end, \n, after he plundered the stronghold \n, on the proud height of Troy. \n, He saw the townlands \n, and learned the minds of many distant men, \n, and weathered many bitter nights and days \n, in his deep heart at sea, while he fought only \n, to save his life, to bring his shipmates home. \n, But not by will nor valor could he save them, \n, for their own recklessness destroyed them all— \n, children and fools, they killed and feasted on \n, the cattle of Lord Helios, the Sun, \n, and he who moves all day through heaven \n, took from their eyes the dawn of their return. \n, Of these adventures, Muse, daughter of Zeus, \n, tell us in our time, lift the great song again. \n, Begin when all the rest who left behind them \n, headlong death in battle or at sea \n, had long ago returned, while he al
, as men say—in the fastness of Olympos. \n, Never a tremor of wind, or a splash of rain, \n, no errant snowflake comes to stain that heaven, \n, so calm, so vaporless, the world of light. \n, Here, where the gay gods live their days of pleasure, \n, the grey-eyed one withdrew, leaving the princess. \n, And now Dawn took her own fair throne, awaking \n, the girl in the sweet gown, still charmed by dream. \n, Down through the rooms she went to tell her parents, \n, whom she found still at home: her mother seated \n, near the great hearth among her maids—and twirling \n, out of her distaff yarn dyed like the sea—; \n, her father at the door, bound for a council \n, of princes on petition of the gentry. \n, She went up close to him and softly said: \n, “My dear Papa, could you not send the mule cart \n, around for me—the gig with pretty wheels? \n, I must take all our things and get them washed \n, at the river pools; our linen is all soiled. \n, And you should wear fresh clothing, going to council \n, with counselors and first men of the realm. \n, Remember your five sons at home: though two \n, are married, we have still three bachelor sprigs; \n, they will have none but laundered clothes each time \n, they go to the dancing. See what I must think of!” \n, She had no word to say of her own wedding, \n, though her keen father saw her blush. Said he: \n, “No mules would I deny you, child, nor anything. \n, Go along, now; the grooms will bring your gig \n, with pretty wheels and the cargo box upon it.” \n, He spoke to the stableman, who soon brought round \n, the cart, low-wheeled and nimble; \n, harnessed the mules, and backed them in the traces. \n, Meanwhile the girl fetched all her soiled apparel \n, to bundle in the polished wagon box. \n, Her mo ...
# Name: text, dtype: object

# %%
print('Type:', type(df['tokens'][0]))
print('Lenght:',len(df['tokens'][0]))
print(df['tokens'][:6])
# Out:
# Type: <class 'list'>
# Lenght: 1939
# 0                                     [sing, muse, tell, story, man, skilled, ways, contending, wanderer, harried, years, end, plundered, stronghold, proud, height, troy, saw, townlands, learned, minds, many, distant, men, weathered, many, bitter, nights, days, deep, heart, sea, fought, save, life, bring, shipmates, home, valor, could, save, recklessness, destroyed, children, fools, killed, feasted, cattle, lord, helios, sun, moves, day, heaven, took, eyes, dawn, return, adventures, muse, daughter, zeus, tell, us, time, lift, great, song, begin, rest, left, behind, headlong, death, battle, sea, long, ago, returned, alone, still, hungered, home, wife, ladyship, kalypso, clung, seahollowed, caves, nymph, immortal, beautiful, craved, long, years, seasons, wheeling, brought, around, point, ...]
# 1                                                           [primal, dawn, spread, eastern, sky, fingers, pink, light, odysseus, true, son, stood, drew, tunic, mantle, slung, swordbelt, newedged, sword, tied, smooth, feet, good, rawhide, sandals, left, room, god, brilliance, upon, found, criers, clarion, voices, told, muster, unshorn, akhaians, full, assembly, call, sang, men, came, streaming, filled, assembly, ground, entered, spear, hand, quick, hounds, heel, athena, lavished, sunlit, grace, held, eye, multitude, old, men, made, way, took, father, chair, lord, aigyptios, bent, sage, years, opened, assembly, man, son, served, great, odysseus, gone, decked, ships, wild, horse, country, troy, spearman, antiphos, name, ravenous, kyklops, cave, destroyed, last, feast, men, sons, old, man, ...]
# 2    [sun, rose, flawless, brimming, sea, sky, brazen, brightening, gods, immortal, mortal, men, plowlands, kind, grain, facing, sunrise, voyagers, lay, pylos, town, compact, stronghold, neleus, shore, black, bulls, offered, people, bluemaned, god, makes, islands, tremble, congregations, hundred, strong, led, bulls, apiece, sacrifice, taking, tripes, eat, altars, thighbones, fat, lay, burning, god, put, furled, sail, beached, ship, telemakhos, hung, back, disembarking, athena, turned, said, least, shyness, telemakhos, came, across, open, sea, find, great, earth, hides, father, doom, came, upon, go, old, nestor, master, charioteer, may, broach, storehouse, mind, ask, courtesy, wisdom, tell, history, lies, clearheaded, telemakhos, replied, mentor, approach, practice, elaborate, speeches, ...]
# 3           [vales, sharp, ravines, lakedaimon, travellers, drove, menelaos, mansion, found, double, wedding, feast, son, daughter, long, ago, troy, pledged, heir, great, akhilleus, breaker, men, match, gods, ripened, must, send, chariot, train, town, glory, myrmidons, day, brought, alektor, daughter, marry, tall, scion, megapenthes, born, slave, girl, long, war, gods, never, granted, helen, child, bring, sunlit, world, first, roselipped, hermione, girl, like, palegold, goddess, aphrodite, great, hall, happiness, feasted, neighbors, menelaos, kin, holy, minstrel, harped, sang, lithe, tumblers, moved, song, spins, handsprings, company, telemakhos, nestor, son, pulled, horses, main, gate, king, companions, arms, etedeneus, going, outside, caught, sight, turned, passed, court, hall, tell, ...]
# 4                                            [dawn, came, couch, reclining, leaving, lord, tithonos, brilliant, side, fresh, light, arms, gods, men, master, heaven, high, thunder, zeus, went, place, among, gods, assembled, hearing, athena, tell, odysseus, woe, vexed, still, sojourning, sea, chambers, kalypso, said, father, zeus, gods, bliss, forever, let, man, holding, scepter, king, think, mild, kind, virtuous, let, cruel, practice, evil, ways, odysseus, ruled, remember, fatherhood, mercy, reign, meanwhile, lives, grieves, upon, island, thralldom, nymph, stir, fare, homeward, ship, left, fitted, oars, crewmen, companions, pull, broad, back, sea, murder, hatched, high, sea, son, sought, news, father, holy, lands, pylos, lakedaimon, summoner, cloud, replied, child, odd, complaints, let, ...]
# 5           [far, gone, weariness, oblivion, noble, enduring, man, slept, athena, night, went, land, phaiakians, entering, city, days, gone, men, held, hypereia, country, wide, dancing, grounds, near, overbearing, kyklopes, whose, power, could, turned, pillage, phaidkians, migrated, thence, nausithoos, settle, new, world, across, sea, skheria, island, first, captain, walled, promontory, built, homes, shrines, parcelled, black, land, plow, gone, long, ago, death, alkinoes, ruled, heaven, gave, wisdom, night, goddess, greyeyed, athena, entered, palace, alkinods, make, sure, odysseus, voyage, home, took, way, painted, bedchamber, young, girl, lay, fast, asleep, fine, mould, feature, seemed, goddess, daughter, alkinods, nausikaa, either, side, graces, might, slept, maids, sleeping, bright, ...]
# Name: tokens, dtype: object

# %%
e.check_df(df)
# Out:
# No missing values
#
# df columns: Index(['author', 'year', 'title', 'book_num', 'text', 'num_lines',
#        'num_sentences', 'num_words', 'tokens', 'num_tokens'],
#       dtype='object')
#
# Shape: (24, 10)

# %%
# Create output directory if it doesn't exist
output_filepath = f"/Users/debr/odysseys_en/dataframed/Odyssey_{translator}_DataFrame.csv"
os.makedirs(os.path.dirname(output_filepath), exist_ok=True)

# save df to csv
df.to_csv(output_filepath, index=False)

print(f"Normalization complete. File saved to: {output_filepath}")
# Out:
# Normalization complete. File saved to: /Users/debr/odysseys_en/dataframed/Odyssey_Fitzgerald_DataFrame.csv
