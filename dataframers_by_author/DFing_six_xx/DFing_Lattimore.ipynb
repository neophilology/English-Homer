# %% [markdown]
# # Dataframer: Richmond Latimore's Odyssey to Pandas DF
#
# ### [—————————————pipeline—————————————]
# ### »——raw—»—clean—»—normalize—»—DATAFRAME——»
#
# Here are some transformation and frequencies for future exploratory analysis of Green's Odyssey.
#
# Columns: author, year, title, book_num, text, num_lines, num_sentences, num_words,

# %%
# library imports
import os

import numpy as np
import pandas as pd

import re
import nltk

# %%
# Display options
pd.set_option("display.max_colwidth", None)  # Prevent truncation of long values
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.expand_frame_repr", False)  # Prevent wrapping in DataFrames

# %%
# Visualization libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/Users/debr/English-Homer') 
import bard_visualization as viz# This will apply the visualization settings
from bard_visualization import color_palette 
sys.path.append('/Users/debr/English-Homer/functions') 
import e_nlp as e
# Out:
# Functions for NLP are live! use e.<function> to call them.
# Downloading NLTK resources...
# Download complete.
# Stopwords customized:
#   Added: {"'", "'and", 'nine', 'two', 'seven', 'eight', 'ten', 'five', 'one', 'n', 'six', 'three', 'four'}
#   Removed: {''}
#   Total stopwords: 211
# Punctuation customized:
#   Keeping: {'-', ''}
#   Additional removals: {'”', '\\', '…', '—', '-', '‘', '’', '“'}
#   Punctuation to be removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~—‘’“”…
# [nltk_data] Downloading package punkt_tab to /Users/debr/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# TO UPDATE
translator = "Lattimore"
book_breaker = "BOOK"

# Check Paths
filepath = f"/Users/debr/odysseys_en/Normalized_txts/Odyssey_{translator}_Normalized.txt"
output_path = f"/Users/debr/English-Homer/dataframers_by_author/{translator}_DFed/"
os.makedirs(os.path.dirname(output_path), exist_ok=True)
output_path_plots = f"{output_path}/plots/"
os.makedirs(os.path.dirname(output_path_plots), exist_ok=True)

# READING FILE TO extracted_lines
with open(filepath, 'r') as file:
    extracted_lines = file.readlines()

text = "".join(extracted_lines)

# %%
# Function to split the text into books

#books = string_into_books(text, book_breaker)
books = e.list_into_books(extracted_lines, book_breaker)

# Verify the results
print(f"Found {len(books)} books")
for i, book in enumerate(books):
    print(f"Book {i+1} starts with: {book[0]}")
    print(f"Book {i+1} has {len(book)} lines")
# Out:
# Found 24 books
# Book 1 starts with: Tell me, Muse, of the man of many ways, who was driven
#
# Book 1 has 455 lines
# Book 2 starts with: Now when the young Dawn showed again with her rosy fingers, the dear
#
# Book 2 has 442 lines
# Book 3 starts with: Helios, leaving behind the lovely standing waters, rose up
#
# Book 3 has 510 lines
# Book 4 starts with: They came into the cavernous hollow of Lakedaimon
#
# Book 4 has 871 lines
# Book 5 starts with: Now Dawn rose from her bed, where she lay by haughty Tithonos,
#
# Book 5 has 507 lines
# Book 6 starts with: So long-suffering great Odysseus slept in that place
#
# Book 6 has 334 lines
# Book 7 starts with: So long-suffering great Odysseus prayed, in that place,
#
# Book 7 has 353 lines
# Book 8 starts with: Then when the young Dawn showed again with her rosy fingers,
#
# Book 8 has 600 lines
# Book 9 starts with: Then resourceful Odysseus spoke in turn and answered him: ‘O great
#
# Book 9 has 568 lines
# Book 10 starts with: ‘We came next to the Aiolian island, whereAiolos
#
# Book 10 has 587 lines
# Book 11 starts with: ‘Now when we had gone down again to the sea and our vessel,
#
# Book 11 has 652 lines
# Book 12 starts with: ‘Now when our ship had left the stream of the Ocean river, and come back
#
# Book 12 has 460 lines
# Book 13 starts with: So he spoke, and all of them stayed stricken to silence, held in thrall by the
#
# Book 13 has 447 lines
# Book 14 starts with: But Odysseus himself left the harbor and ascended a rugged
#
# Book 14 has 549 lines
# Book 15 starts with: At this time, Pallas Athene made her way into wide-spaced
#
# Book 15 has 571 lines
# Book 16 starts with: These two in the shelter, Odysseus and the noble
#
# Book 16 has 490 lines
# Book 17 starts with: But when the young Dawn showed again with her rosy fingers,
#
# Book 17 has 611 lines
# Book 18 starts with: And now there arrived a public beggar, who used to go begging through
#
# Book 18 has 439 lines
# Book 19 starts with: Now great Odysseus still remained in the hall, pondering how, with the
#
# Book 19 has 619 lines
# Book 20 starts with: Then the noble Odysseus bedded down in the forecourt, and spread
#
# Book 20 has 396 lines
# Book 21 starts with: But now the goddess, gray-eyed Athene, put it in the mind of the daughter
#
# Book 21 has 430 lines
# Book 22 starts with: Now resourceful Odysseus stripped his rags from him, and sprang up atop
#
# Book 22 has 512 lines
# Book 23 starts with: The old woman, laughing loudly, went to the upper chamber
#
# Book 23 has 380 lines
# Book 24 starts with: Hermes of Kyllene summoned the souls of the suitors to come forth, and in
#
# Book 24 has 561 lines

# %%
# Books (lists) into DataFrame
df = e.book_into_df(f"{translator}", "1965", "The Odyssey", books)

# Apply functions & add new columns
df['num_lines'] = df['text'].apply(e.count_lines)
df['num_sentences'] = df['text'].apply(e.count_sentences)
df['num_words'] = df['text'].apply(e.count_words)

# %%
# Initialize the pipeline
nlp = e.NLPPipeline(language='english')

# Customize stopwords
nlp.customize_stopwords(
    include={'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten',
             "'", 'n', "'and",},
    exclude={''}
)
# Customize punctuation
nlp.customize_punctuation(
    keep={'-', ""},  # Keep hyphens and apostrophes
    remove={r'…', '—','”','’','“', '‘', '-', '\\'}  # Additional characters to remove
)

# Process with default pipeline (lowercase -> tokenize -> remove punctuation -> remove stopwords)
df = nlp.process_dataframe(df, 'text', 'tokens')
df['num_tokens'] = df['tokens'].map(len)
# Out:
# Stopwords customized:
#   Added: {"'", 'nine', "'and", 'seven', 'eight', 'ten', 'n', 'five', 'one', 'two', 'six', 'three', 'four'}
#   Removed: {''}
#   Total stopwords: 211
# Punctuation customized:
#   Keeping: {'-', ''}
#   Additional removals: {'”', '‘', '…', '—', '-', '\\', '’', '“'}
#   Punctuation to be removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~—‘’“”…

# %%
print('Type:', type(df['text'][0]))
print('Lenght:',len(df['text'][0]))
print(df['text'][:6])
# Out:
# Type: <class 'list'>
# Lenght: 455
ets for you. In this way it will be so much more\n, becoming than for you to go there  on foot, for the washing places are a\n, long way from the city.’\n, So the gray-eyed Athene spoke and went away from her\n, to Olympos, where the abode of the gods stands firm and unmoving\n, forever, they say, and is not shaken with winds nor spattered with rains, nor\n, does snow pile ever there, but the shining bright air  stretches cloudless\n, away, and the white light glances upon it.\n, And there, and all their days, the blessed gods take their pleasure.\n, There the Gray-eyed One went, when she had talked with the young girl.\n, And the next the Dawn came, throned in splendor, and wakened the\n, well-robed girl Nausikaa, and she wondered much at her dreaming,\n,  and went through the house, so as to give the word to her parents, to her\n, dear father and her mother. She found them within there; the queen was\n, sitting by the fireside with her attendant women, turning sea-purple yarn\n, on a distaff; her father\n, she met as he was going out the door to the council\n,  of famed barons, where the proud Phaiakians used to summon him.\n, She stood very close up to her dear father and spoke to him: ‘Daddy dear,\n, will you not have them harness me the wagon, the high one with the good\n, wheels, so that I can take the clothing to the river and wash it? Now it is\n, lying about, all dirty,  and you yourself, when you sit among the first\n, men in council and share their counsels, ought to have clean clothing about\n, you; and also, you have five dear sons who are grown in the palace,\n, Odysseus wakened by Naus ...
# Name: text, dtype: object

# %%
print('Type:', type(df['tokens'][0]))
print('Lenght:',len(df['tokens'][0]))
print(df['tokens'][:6])
# Out:
# Type: <class 'list'>
# Lenght: 2277
# 0                                                [tell, muse, man, many, ways, driven, far, journeys, sacked, troy, sacred, citadel, many, whose, cities, saw, whose, minds, learned, many, pains, suffered, spirit, wide, sea, struggling, life, homecoming, companions, even, could, save, companions, hard, though, strove, destroyed, wild, recklessness, fools, devoured, oxen, helios, sun, god, took, away, day, homecoming, point, goddess, daughter, zeus, speak, begin, story, others, many, fled, sheer, destruction, home, escaped, sea, fighting, alone, longing, wife, homecoming, detained, queenly, nymph, kalypso, bright, among, goddesses, hollowed, caverns, desiring, husband, circling, years, year, came, gods, spun, time, homecoming, ithaka, even, free, trials, among, people, gods, pitied, except, poseidon, remained, relentlessly, ...]
# 1                                                          [young, dawn, showed, rosy, fingers, dear, son, odysseus, stirred, sleeping, put, clothes, slung, sharp, sword, shoulder, underneath, shining, feet, bound, fair, sandals, went, way, chamber, like, god, presence, gave, word, clearvoiced, heralds, summon, proclamation, assembly, flowinghaired, achaians, heralds, made, cry, men, assembled, swiftly, assembled, place, together, went, way, assembly, hands, holding, bronze, spear, alone, pair, lightfooted, dogs, went, athene, drifted, enchantment, grace, upon, people, eyes, came, forward, sat, father, seat, elders, made, way, first, speak, hero, aigyptios, bent, age, seen, things, beyond, number, dear, son, antiphos, spearman, gone, godlike, odysseus, ilion, land, good, horses, hollow, ships, wild, cyclops, killed, deep, ...]
# 2                       [helios, leaving, behind, lovely, standing, waters, rose, brazen, sky, shine, upon, immortals, also, mortal, men, across, graingiving, farmland, came, pylos, neleus, strongfounded, citadel, people, shore, sea, making, sacrifice, bulls, black, darkhaired, earthshaker, settlements, hundred, holdings, bulls, provided, tasted, entrails, burned, god, thigh, bones, others, put, straight, balanced, ship, took, sails, stowed, moored, landed, telemachos, stepped, ship, athene, went, first, grayeyed, goddess, athene, first, spoke, telemachos, need, modesty, sailed, open, sea, find, news, father, soil, covers, fate, met, come, go, straight, nestor, breaker, horses, know, intelligence, hidden, inside, must, entreat, speak, whole, truth, tell, falsehood, thoughtful, thoughtful, telemachos, said, answer, mentor, ...]
# 3                           [came, cavernous, hollow, lakedaimon, made, way, house, glorious, menelaos, found, house, giving, many, townsmen, wedding, feast, son, stately, daughter, girl, sending, son, achilleus, breaker, battalions, troy, land, first, nodded, head, promised, give, gods, bringing, pass, marriage, sending, way, horses, chariots, famous, city, myrmidons, neoptolemos, lord, brought, alektor, daughter, sparta, give, powerful, megapenthes, young, grown, son, born, slave, woman, gods, gave, children, helen, borne, first, child, lovely, hermione, beauty, aphrodite, golden, neighbors, townsmen, glorious, menelaos, feasting, great, house, high, roof, taking, ease, among, stepped, inspired, singer, playing, lyre, among, dancers, acrobats, led, measures, song, dance, revolving, among, hero, telemachos, shining, son, ...]
# 4                                                              [dawn, rose, bed, lay, haughty, tithonos, carrying, light, immortal, gods, mortals, gods, came, took, places, session, among, zeus, thunders, high, power, greatest, athene, spoke, many, cares, odysseus, remembering, though, nymph, house, still, thought, father, zeus, blessed, gods, everlasting, longer, let, sceptered, king, eager, gentle, kind, whose, thought, schooled, justice, let, always, rather, harsh, act, severely, seeing, way, people, lord, remembers, godlike, odysseus, kind, like, father, lies, away, island, suffering, strong, pains, palace, nymph, kalypso, detains, constraint, make, way, country, ships, companions, convey, back, across, sea, wide, ridges, determined, murder, dear, son, way, home, went, quest, news, father, pylos, sacrosanct, glorious, ...]
# 5    [longsuffering, great, odysseus, slept, place, exhaustion, sleep, weariness, athene, went, way, district, city, phaiakian, men, formerly, lived, spacious, land, hypereia, next, cyclopes, men, overbearing, kept, harrying, greater, strength, godlike, nausithoos, removed, led, migration, settled, scheria, far, away, men, eat, bread, driven, wall, city, built, houses, made, temples, gods, allotted, holdings, submitted, fate, gone, hades, alkinoos, learned, designs, gods, ruled, house, grayeyed, goddess, athene, went, devising, homecoming, greathearted, odysseus, went, ornate, chamber, girl, sleeping, like, immortal, goddesses, stature, beauty, nausikaa, daughter, greathearted, alkinoos, beside, handmaidens, beauty, given, graces, slept, either, side, post, shining, doors, closed, drifted, like, breath, wind, girl, slept, ...]
# Name: tokens, dtype: object

# %%
#Boolean check for missing values
e.check_df(df)
# Out:
# No missing values
#
# df columns: Index(['author', 'year', 'title', 'book_num', 'text', 'num_lines',
#        'num_sentences', 'num_words', 'tokens', 'num_tokens'],
#       dtype='object')
#
# Shape: (24, 10)

# %%
# Create output directory if it doesn't exist
output_filepath = f"/Users/debr/odysseys_en/dataframed/Odyssey_{translator}_DataFrame.csv"
os.makedirs(os.path.dirname(output_filepath), exist_ok=True)

# save df to csv
df.to_csv(output_filepath, index=False)

print(f"Normalization complete. File saved to: {output_filepath}")
# Out:
# Normalization complete. File saved to: /Users/debr/odysseys_en/dataframed/Odyssey_Lattimore_DataFrame.csv
